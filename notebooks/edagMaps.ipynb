# %%
import json
import os
import pandas as pd
from collections import Counter

# %% [markdown]
# Vamos a analizar la calidad de los datos en los archivos JSON siguiendo estos puntos:
#
# ### 🔍 **Análisis de Calidad de Datos**
# 1. **Validez del JSON** → Verificamos si los archivos tienen una estructura JSON válida.
# 2. **Valores nulos o faltantes** → Campos como `text`, `pics`, y `resp` pueden estar vacíos o `null`.
# 3. **Distribución de ratings** → Revisamos si hay valores atípicos en `rating` (debe estar entre 1 y 5).
# 4. **Timestamps** → Validamos si `time` es una fecha coherente.
# 5. **Duplicados** → Revisamos si hay registros repetidos (`user_id`, `gmap_id`).
# 6. **Valores categóricos** → Evaluamos si `category` en metadata_sitios es consistente.

# %%
# Función para cargar archivos JSON
def load_json(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        return [json.loads(line) for line in file]

# Función para analizar la calidad de los datos
def analyze_data(file_path):
    data = load_json(file_path)
    df = pd.DataFrame(data)
    
    print(f"\n📌 Análisis del archivo: {file_path}\n")
    
    # 1. Valores nulos o faltantes
    print("🔍 Valores nulos por columna:")
    print(df.isnull().sum())
    
    # 2. Distribución de ratings
    if 'rating' in df.columns:
        print("\n📊 Distribución de ratings:")
        print(df['rating'].value_counts())
    
    # 3. Verificación de timestamps
    if 'time' in df.columns:
        df['time'] = pd.to_datetime(df['time'], unit='ms', errors='coerce')
        print("\n🕒 Rango de fechas en 'time':")
        print(f"Desde: {df['time'].min()} - Hasta: {df['time'].max()}")
    
    # 4. Duplicados
    print("\n🛑 Duplicados en 'user_id' y 'gmap_id':")
    if 'user_id' in df.columns and 'gmap_id' in df.columns:
        print(f"Duplicados por usuario: {df.duplicated('user_id').sum()}")
        print(f"Duplicados por gmap_id: {df.duplicated('gmap_id').sum()}")
    
    # 5. Análisis de categorías
    if 'category' in df.columns:
        categories = Counter([item for sublist in df['category'].dropna() for item in sublist])
        print("\n📌 Categorías más frecuentes:")
        print(categories.most_common(10))
    
    print("\n✅ Análisis completado!\n")

# %% [markdown]
# ## California

# %%
# Ruta de los archivos JSON
directory = "./dataMaps/review-California-20250209T110450Z-001/review-California/"  # Cambia esto a tu directorio con los archivos JSON
json_files = [os.path.join(directory, f) for f in os.listdir(directory) if f.endswith('.json')]

# %%
# Analizar los archivos JSON
for file in json_files:
    analyze_data(file)
# Lista para almacenar los DataFrames
all_data = []

# Cargar y combinar los datos de cada archivo JSON
for file in json_files:
    data = load_json(file)
    df = pd.DataFrame(data)
    all_data.append(df)

# Combinar todos los DataFrames en uno solo
combined_df = pd.concat(all_data, ignore_index=True)
combined_df.to_csv("./CSV/California.csv", index=False)
# Out:
# 📌 Análisis del archivo: ./dataMaps/review-California-20250209T110450Z-001/review-California/1.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        60865
# pics       144368
# resp       133065
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    101348
# 4     22103
# 1     11903
# 3     10384
# 2      4262
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2004-04-07 00:00:00 - Hasta: 2021-09-09 01:00:32.337000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 31569
# Duplicados por gmap_id: 142245
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-California-20250209T110450Z-001/review-California/10.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        65500
# pics       144932
# resp       136182
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    92373
# 4    30456
# 3    13995
# 1     8356
# 2     4820
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2004-04-20 00:00:00 - Hasta: 2021-06-21 06:36:33.963000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 24686
# Duplicados por gmap_id: 146871
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-California-20250209T110450Z-001/review-California/11.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        67256
# pics       144835
# resp       138388
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    93342
# 4    30772
# 3    13630
# 1     7650
# 2     4606
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2004-03-12 00:00:00 - Hasta: 2021-06-20 04:55:39.639000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 24414
# Duplicados por gmap_id: 147644
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-California-20250209T110450Z-001/review-California/12.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        66408
# pics       144857
# resp       140407
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    89318
# 4    33411
# 3    15040
# 1     7407
# 2     4824
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 1990-12-31 00:00:00 - Hasta: 2021-06-19 07:45:15.753000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 25999
# Duplicados por gmap_id: 148296
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-California-20250209T110450Z-001/review-California/13.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        67314
# pics       144610
# resp       137339
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    91333
# 4    32414
# 3    14374
# 1     7125
# 2     4754
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2006-04-20 00:00:00 - Hasta: 2021-06-18 12:55:34.547000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 23220
# Duplicados por gmap_id: 148040
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-California-20250209T110450Z-001/review-California/14.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        67776
# pics       144103
# resp       138861
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    89766
# 4    34420
# 3    14439
# 1     6715
# 2     4660
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2006-03-10 00:00:00 - Hasta: 2021-06-17 19:55:45.744000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 24282
# Duplicados por gmap_id: 148389
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-California-20250209T110450Z-001/review-California/15.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        67066
# pics       144545
# resp       137736
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    90544
# 4    33468
# 3    14537
# 1     6888
# 2     4563
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 1990-12-31 00:00:00 - Hasta: 2021-06-16 23:12:59.250000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 23834
# Duplicados por gmap_id: 147949
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-California-20250209T110450Z-001/review-California/16.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        69908
# pics       145766
# resp       139429
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    86468
# 4    34983
# 3    16608
# 1     6649
# 2     5292
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 1990-12-31 00:00:00 - Hasta: 2021-06-16 07:31:04.362000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 26449
# Duplicados por gmap_id: 148815
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-California-20250209T110450Z-001/review-California/17.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        68463
# pics       143883
# resp       138734
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    92855
# 4    33738
# 3    13736
# 1     5402
# 2     4269
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 1990-12-31 00:00:00 - Hasta: 2021-06-15 15:25:13.212000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 24109
# Duplicados por gmap_id: 149247
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-California-20250209T110450Z-001/review-California/18.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        70251
# pics       143591
# resp       142555
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    92667
# 4    33446
# 3    14061
# 1     5483
# 2     4343
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 1990-12-31 00:00:00 - Hasta: 2021-06-15 00:12:20.412000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 28783
# Duplicados por gmap_id: 149318
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-California-20250209T110450Z-001/review-California/2.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        62216
# pics       144500
# resp       132679
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    101594
# 4     22502
# 1     11198
# 3     10575
# 2      4131
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2003-03-31 00:00:00 - Hasta: 2021-08-23 17:48:05.687000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 20091
# Duplicados por gmap_id: 142050
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-California-20250209T110450Z-001/review-California/3.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        62847
# pics       144467
# resp       133259
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    100949
# 4     23046
# 1     10877
# 3     10838
# 2      4290
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2003-03-26 00:00:00 - Hasta: 2021-08-12 20:57:18.887000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 20232
# Duplicados por gmap_id: 142598
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-California-20250209T110450Z-001/review-California/4.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        62952
# pics       144500
# resp       134097
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    100637
# 4     23508
# 3     10851
# 1     10717
# 2      4287
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2003-05-19 00:00:00 - Hasta: 2021-08-04 18:47:22.098000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 20105
# Duplicados por gmap_id: 143144
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-California-20250209T110450Z-001/review-California/5.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        62709
# pics       144160
# resp       133152
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    100589
# 4     23973
# 3     10851
# 1     10440
# 2      4147
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 1990-12-31 00:00:00 - Hasta: 2021-07-31 04:02:13.869000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 20492
# Duplicados por gmap_id: 143420
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-California-20250209T110450Z-001/review-California/6.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        62918
# pics       144560
# resp       134938
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    98203
# 4    25068
# 3    11576
# 1    10680
# 2     4473
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2002-04-23 00:00:00 - Hasta: 2021-07-04 22:16:25.171000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 20865
# Duplicados por gmap_id: 143841
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-California-20250209T110450Z-001/review-California/7.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        61015
# pics       144126
# resp       133675
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    99201
# 4    24952
# 3    11495
# 1     9886
# 2     4466
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2002-04-19 00:00:00 - Hasta: 2021-06-29 05:01:26.497000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 21781
# Duplicados por gmap_id: 144047
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-California-20250209T110450Z-001/review-California/8.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        60733
# pics       144152
# resp       134290
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    99207
# 4    25506
# 3    11205
# 1     9698
# 2     4384
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 1990-12-31 00:00:00 - Hasta: 2021-06-25 23:18:57.286000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 22346
# Duplicados por gmap_id: 144179
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-California-20250209T110450Z-001/review-California/9.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        64767
# pics       144755
# resp       136045
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    92090
# 4    29470
# 3    14044
# 1     9324
# 2     5072
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2005-01-01 00:00:00 - Hasta: 2021-06-22 22:13:29.645000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 22541
# Duplicados por gmap_id: 146486
#
# ✅ Análisis completado!

# %% [markdown]
# El análisis de los datos muestra información valiosa sobre la calidad de los archivos JSON del estado de California. Aquí están algunos puntos clave a  considerar:
#
# 1. **Valores Nulos**:
#    - Los campos `text`, `pics`, y `resp` tienen una cantidad significativa de valores faltantes (60865, 144368, y 133065 respectivamente). Esto podría indicar que muchos registros no tienen estos campos llenos.
#
# 2. **Distribución de Ratings**:
#    - La mayoría de las calificaciones son 5 (101,348 registros), lo que podría ser un patrón importante a revisar. Si estás buscando un análisis más equilibrado, esto podría influir en el modelo que estés construyendo o en el análisis de comportamiento.
#
# 3. **Rango de Fechas en 'time'**:
#    - El rango de fechas va desde 2004 hasta 2021. Esto puede ser útil si necesitas revisar la temporalidad de los datos o si hay una gran cantidad de registros antiguos que podrían no ser relevantes.
#
# 4. **Duplicados**:
#    - Hay una cantidad considerable de duplicados por `gmap_id` (146,486). Deberías decidir si estos duplicados son un problema y cómo manejarlos (por ejemplo, eliminarlos o consolidarlos).
#
# 5. **Análisis de Categorías**:
#    - Si tienes campos con categorías, podrías profundizar en las categorías más frecuentes. Este análisis te puede ayudar a entender mejor cómo se distribuyen los datos en términos de categorías.

# %%
# Ruta de los archivos JSON
directory = "./dataMaps/review-Florida-20250209T110518Z-001/review-Florida/"  # Cambia esto a tu directorio con los archivos JSON
json_files = [os.path.join(directory, f) for f in os.listdir(directory) if f.endswith('.json')]


# Analizar los archivos JSON
for file in json_files:
    analyze_data(file)
    
# Lista para almacenar los DataFrames
all_data = []

# Cargar y combinar los datos de cada archivo JSON
for file in json_files:
    data = load_json(file)
    df = pd.DataFrame(data)
    all_data.append(df)

# Combinar todos los DataFrames en uno solo
combined_df = pd.concat(all_data, ignore_index=True)
combined_df.to_csv("./CSV/Florida.csv", index=False)
# Out:
# 📌 Análisis del archivo: ./dataMaps/review-Florida-20250209T110518Z-001/review-Florida/1.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        49977
# pics       145423
# resp       118033
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    108942
# 4     15200
# 1     14652
# 3      7580
# 2      3626
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2003-05-11 00:00:00 - Hasta: 2021-09-09 16:22:53.205000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 29170
# Duplicados por gmap_id: 142287
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Florida-20250209T110518Z-001/review-Florida/10.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        59671
# pics       145581
# resp       129424
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    94305
# 4    27506
# 3    13162
# 1     9840
# 2     5187
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2008-05-12 00:00:00 - Hasta: 2021-06-18 02:27:40.099000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 28084
# Duplicados por gmap_id: 148147
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Florida-20250209T110518Z-001/review-Florida/11.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        61886
# pics       144999
# resp       130129
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    91947
# 4    29864
# 3    14055
# 1     8689
# 2     5445
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2005-05-17 00:00:00 - Hasta: 2021-06-17 09:01:14.568000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 30701
# Duplicados por gmap_id: 149222
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Florida-20250209T110518Z-001/review-Florida/12.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        58611
# pics       145186
# resp       128800
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    94734
# 4    27198
# 3    12695
# 1    10225
# 2     5148
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2008-05-09 18:16:05.242000 - Hasta: 2021-06-16 22:24:30.128000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 25126
# Duplicados por gmap_id: 148017
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Florida-20250209T110518Z-001/review-Florida/13.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        61321
# pics       145042
# resp       135537
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    88972
# 4    30352
# 3    15285
# 1     9440
# 2     5951
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2003-05-22 00:00:00 - Hasta: 2021-06-16 02:08:03.407000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 28419
# Duplicados por gmap_id: 149263
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Florida-20250209T110518Z-001/review-Florida/14.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        63401
# pics       144310
# resp       130117
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    88655
# 4    32443
# 3    15591
# 1     7853
# 2     5458
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2008-12-27 17:53:41.415000 - Hasta: 2021-06-14 18:19:48.056000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 29631
# Duplicados por gmap_id: 149461
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Florida-20250209T110518Z-001/review-Florida/15.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        58588
# pics       143276
# resp       125710
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    95294
# 4    29527
# 3    13132
# 1     7348
# 2     4699
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2003-05-11 00:00:00 - Hasta: 2021-06-14 01:11:21.634000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 27160
# Duplicados por gmap_id: 148938
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Florida-20250209T110518Z-001/review-Florida/16.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        58214
# pics       144414
# resp       132271
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    94926
# 4    28555
# 3    12971
# 1     8476
# 2     5072
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2003-01-01 00:00:00 - Hasta: 2021-06-13 12:09:53.747000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 26404
# Duplicados por gmap_id: 148394
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Florida-20250209T110518Z-001/review-Florida/17.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        61861
# pics       144918
# resp       135042
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    94388
# 4    30014
# 3    13202
# 1     7496
# 2     4900
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2007-05-16 00:00:00 - Hasta: 2021-06-13 01:55:05.627000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 28045
# Duplicados por gmap_id: 148972
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Florida-20250209T110518Z-001/review-Florida/18.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        55883
# pics       142265
# resp       132821
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    95414
# 4    30910
# 3    13001
# 1     6318
# 2     4357
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2008-11-13 18:09:19.729000 - Hasta: 2021-06-12 05:15:37.069000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 35359
# Duplicados por gmap_id: 149336
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Florida-20250209T110518Z-001/review-Florida/19.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        53373
# pics       139821
# resp       130200
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    94818
# 4    31034
# 3    13078
# 1     6250
# 2     4820
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2003-06-07 00:00:00 - Hasta: 2021-06-09 04:34:05.046000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 41056
# Duplicados por gmap_id: 149563
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Florida-20250209T110518Z-001/review-Florida/2.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        52648
# pics       145253
# resp       117084
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    109178
# 4     16128
# 1     13419
# 3      7667
# 2      3608
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2003-05-21 00:00:00 - Hasta: 2021-08-20 00:47:48.815000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 21393
# Duplicados por gmap_id: 142292
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Florida-20250209T110518Z-001/review-Florida/3.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        53139
# pics       144993
# resp       117861
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    108466
# 4     16550
# 1     13505
# 3      7811
# 2      3668
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2007-10-19 14:37:54.075000 - Hasta: 2021-08-07 00:19:16.378000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 21539
# Duplicados por gmap_id: 142903
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Florida-20250209T110518Z-001/review-Florida/4.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        53905
# pics       145189
# resp       119579
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    108120
# 4     17225
# 1     12722
# 3      8139
# 2      3794
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2007-10-26 16:16:14.750000 - Hasta: 2021-07-31 03:23:14.575000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 21672
# Duplicados por gmap_id: 143326
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Florida-20250209T110518Z-001/review-Florida/5.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        52514
# pics       145094
# resp       119222
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    106586
# 4     17677
# 1     13295
# 3      8601
# 2      3841
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2005-05-18 00:00:00 - Hasta: 2021-07-01 18:08:30.367000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 22910
# Duplicados por gmap_id: 143751
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Florida-20250209T110518Z-001/review-Florida/6.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        52134
# pics       145126
# resp       119346
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    106721
# 4     18131
# 1     12553
# 3      8766
# 2      3829
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2007-06-29 14:54:14.364000 - Hasta: 2021-06-26 03:10:43.256000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 23619
# Duplicados por gmap_id: 144134
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Florida-20250209T110518Z-001/review-Florida/7.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        55816
# pics       145195
# resp       125618
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    98929
# 4    23404
# 3    11611
# 1    11273
# 2     4783
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2003-05-09 00:00:00 - Hasta: 2021-06-22 01:06:22.813000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 24203
# Duplicados por gmap_id: 146394
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Florida-20250209T110518Z-001/review-Florida/8.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        57191
# pics       144656
# resp       122099
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    96220
# 4    25519
# 3    12198
# 1    10922
# 2     5141
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2008-12-16 23:03:28.106000 - Hasta: 2021-06-20 11:25:35.930000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 25296
# Duplicados por gmap_id: 147631
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Florida-20250209T110518Z-001/review-Florida/9.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        59377
# pics       145069
# resp       125708
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    94375
# 4    28912
# 3    12967
# 1     8580
# 2     5166
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2003-05-14 00:00:00 - Hasta: 2021-06-19 05:21:10.484000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 31570
# Duplicados por gmap_id: 148752
#
# ✅ Análisis completado!

# %% [markdown]
# El análisis de los datos muestra lo siguiente:
#
# 1. **Valores Nulos por Columna**:
#    - Las columnas `user_id`, `name`, `time`, `rating`, y `gmap_id` no tienen valores nulos, lo que significa que todos los registros tienen datos completos en estas columnas.
#    - Las columnas `text`, `pics`, y `resp` tienen valores faltantes:
#      - `text` tiene 49,977 valores nulos.
#      - `pics` tiene 145,423 valores nulos.
#      - `resp` tiene 118,033 valores nulos.
#
#    Esto sugiere que una gran parte de los registros no contienen datos en estos campos, lo cual podría ser importante dependiendo de cómo planeas utilizar estos datos.
#
# 2. **Distribución de Ratings**:
#    - La mayoría de los registros tienen una calificación de 5 (108,942 registros), lo que es una distribución sesgada. Esto podría influir en el análisis si buscas patrones de comportamiento de los usuarios.
#    - Otras calificaciones están distribuidas de la siguiente manera:
#      - 4: 15,200
#      - 1: 14,652
#      - 3: 7,580
#      - 2: 3,626
#
#    Si la mayoría de las calificaciones son 5, puede ser útil considerar si este sesgo afecta los modelos de predicción o el análisis que deseas realizar.
#
# 3. **Rango de Fechas en 'time'**:
#    - Las fechas en la columna `time` varían desde el 11 de mayo de 2003 hasta el 9 de septiembre de 2021. Esto indica que los datos cubren un período largo de tiempo.
#    - Podrías analizar la evolución temporal de las calificaciones o el comportamiento de los usuarios a lo largo del tiempo.
#
# 4. **Duplicados por `gmap_id`**:
#    - Existen 148,752 duplicados en la columna `gmap_id`. Esto significa que muchos registros tienen el mismo valor en `gmap_id`, lo que podría indicar entradas repetidas para el mismo lugar o evento. Sería útil investigar si estos duplicados son un problema, y si es necesario eliminar o consolidar los registros.
#
# ### Resumen:
# - Los datos tienen varias columnas con valores nulos, especialmente en `text`, `pics`, y `resp`.
# - La distribución de calificaciones está sesgada hacia las calificaciones de 5.
# - Los registros abarcan un largo rango temporal (desde 2003 hasta 2021).
# - Hay una gran cantidad de duplicados en la columna `gmap_id`, lo cual puede necesitar limpieza de datos.

# %%
# Ruta de los archivos JSON
directory = "./dataMaps/review-Hawaii-20250209T110522Z-001/review-Hawaii/"  # Cambia esto a tu directorio con los archivos JSON
json_files = [os.path.join(directory, f) for f in os.listdir(directory) if f.endswith('.json')]


# Analizar los archivos JSON
for file in json_files:
    analyze_data(file)
    
# Lista para almacenar los DataFrames
all_data = []

# Cargar y combinar los datos de cada archivo JSON
for file in json_files:
    data = load_json(file)
    df = pd.DataFrame(data)
    all_data.append(df)

# Combinar todos los DataFrames en uno solo
combined_df = pd.concat(all_data, ignore_index=True)
combined_df.to_csv("./CSV/Hawaii.csv", index=False)
# Out:
# 📌 Análisis del archivo: ./dataMaps/review-Hawaii-20250209T110522Z-001/review-Hawaii/1.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        62682
# pics       138045
# resp       138601
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    92316
# 4    35135
# 3    14229
# 1     4626
# 2     3694
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2008-07-22 00:00:00 - Hasta: 2021-09-03 03:43:26.411000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 101659
# Duplicados por gmap_id: 146218
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Hawaii-20250209T110522Z-001/review-Hawaii/10.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        67348
# pics       135672
# resp       140014
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    92359
# 4    38319
# 3    14199
# 2     2999
# 1     2124
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2008-07-22 00:00:00 - Hasta: 2021-04-17 00:31:21.955000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 98199
# Duplicados por gmap_id: 149779
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Hawaii-20250209T110522Z-001/review-Hawaii/11.json
#
# 🔍 Valores nulos por columna:
# user_id       0
# name          0
# time          0
# rating        0
# text       1853
# pics       3981
# resp       4075
# gmap_id       0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    2415
# 4    1181
# 3     515
# 1     134
# 2     102
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2011-01-04 05:44:43.352000 - Hasta: 2021-04-14 23:23:46.302000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 237
# Duplicados por gmap_id: 4338
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Hawaii-20250209T110522Z-001/review-Hawaii/2.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        62711
# pics       136689
# resp       140055
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    90036
# 4    36819
# 3    15316
# 1     3929
# 2     3900
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2008-07-22 00:00:00 - Hasta: 2021-06-01 10:58:06.881000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 99692
# Duplicados por gmap_id: 147787
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Hawaii-20250209T110522Z-001/review-Hawaii/3.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        63914
# pics       137588
# resp       137185
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    89151
# 4    37513
# 3    15551
# 1     3895
# 2     3890
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2006-05-08 00:00:00 - Hasta: 2021-05-22 20:52:21.513000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 100368
# Duplicados por gmap_id: 148380
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Hawaii-20250209T110522Z-001/review-Hawaii/4.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        64380
# pics       137333
# resp       140993
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    85229
# 4    40243
# 3    16877
# 2     4124
# 1     3527
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2002-06-13 00:00:00 - Hasta: 2021-05-15 18:21:51.377000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 100603
# Duplicados por gmap_id: 149024
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Hawaii-20250209T110522Z-001/review-Hawaii/5.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        62259
# pics       136477
# resp       136449
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    88398
# 4    38985
# 3    15295
# 2     3857
# 1     3465
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2002-06-13 00:00:00 - Hasta: 2021-05-10 01:04:16.734000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 98759
# Duplicados por gmap_id: 149097
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Hawaii-20250209T110522Z-001/review-Hawaii/6.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        65148
# pics       137803
# resp       138958
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    83716
# 4    40998
# 3    17443
# 2     4225
# 1     3618
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2005-01-01 00:00:00 - Hasta: 2021-05-02 06:34:30.835000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 98878
# Duplicados por gmap_id: 149289
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Hawaii-20250209T110522Z-001/review-Hawaii/7.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        68995
# pics       137994
# resp       138808
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    82817
# 4    41888
# 3    18105
# 2     3983
# 1     3207
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2006-05-08 00:00:00 - Hasta: 2021-04-27 08:03:56.755000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 100510
# Duplicados por gmap_id: 149423
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Hawaii-20250209T110522Z-001/review-Hawaii/8.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        64447
# pics       133539
# resp       138458
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    91327
# 4    38607
# 3    14651
# 2     3136
# 1     2279
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2008-07-22 00:00:00 - Hasta: 2021-04-24 06:17:04.432000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 97472
# Duplicados por gmap_id: 149625
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Hawaii-20250209T110522Z-001/review-Hawaii/9.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        68014
# pics       136524
# resp       141952
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    89807
# 4    39577
# 3    15096
# 2     3209
# 1     2311
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2005-04-15 00:00:00 - Hasta: 2021-04-20 02:49:04.260000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 97304
# Duplicados por gmap_id: 149691
#
# ✅ Análisis completado!

# %% [markdown]
# Aquí tienes un análisis de la respuesta:
#
# ### 1. **Valores nulos por columna**:
#    - **text**: Tiene **62,682** valores nulos, lo cual podría indicar que muchos registros no tienen texto asociado.
#    - **pics**: Tiene **138,045** valores nulos, lo que sugiere que la mayoría de los registros no tienen imágenes.
#    - **resp**: Tiene **138,601** valores nulos, lo que indica que casi todos los registros no tienen respuestas asociadas.
#
#    Las columnas `user_id`, `name`, `time`, `rating`, y `gmap_id` no tienen valores nulos, lo que indica que son esenciales y están completos en todos los registros.
#
# ### 2. **Distribución de ratings**:
#    - El rating **5** es el más frecuente con **92,316** ocurrencias, lo que podría indicar que la mayoría de los registros tienen calificaciones altas.
#    - **Rating 4** sigue con **35,135** registros.
#    - Los ratings **1** y **2** son menos frecuentes, con **4,626** y **3,694** ocurrencias, respectivamente.
#
#    **Conclusión**: La mayoría de los datos parecen tener una calificación alta (4 y 5), lo que puede ser relevante si estás analizando la calidad o el comportamiento de los usuarios.
#
# ### 3. **Rango de fechas en 'time'**:
#    - La fecha más antigua registrada es **2008-07-22**, y la más reciente es **2021-09-03**.
#    - El rango cubre más de 13 años, lo que sugiere que los datos abarcan un largo período, posiblemente importante para un análisis temporal de tendencias.
#
# ### 4. **Duplicados por gmap_id**:
#    - Existen **149,691** registros duplicados para la columna `gmap_id`. Esto puede ser un indicio de que hay datos repetidos o que múltiples registros comparten el mismo identificador de Google Maps.
#
# **Conclusión general**:
#    - El conjunto de datos tiene varios valores nulos, especialmente en las columnas de texto, imágenes y respuestas, lo que sugiere que los datos en estas áreas son incompletos.
#    - Hay una gran cantidad de calificaciones altas (4 y 5), lo que podría indicar que los usuarios tienden a ser positivos en sus valoraciones.
#    - Los duplicados en `gmap_id` requieren una revisión para ver si representan registros redundantes o si hay otros motivos por los cuales los datos están repetidos.

# %%
# Ruta de los archivos JSON
directory = "./dataMaps/review-New_York-20250209T110506Z-001/review-New_York/"  # Cambia esto a tu directorio con los archivos JSON
json_files = [os.path.join(directory, f) for f in os.listdir(directory) if f.endswith('.json')]


# Analizar los archivos JSON
for file in json_files:
    analyze_data(file)
    
# Lista para almacenar los DataFrames
all_data = []

# Cargar y combinar los datos de cada archivo JSON
for file in json_files:
    data = load_json(file)
    df = pd.DataFrame(data)
    all_data.append(df)

# Combinar todos los DataFrames en uno solo
combined_df = pd.concat(all_data, ignore_index=True)
combined_df.to_csv("./CSV/NY.csv", index=False)
# Out:
# 📌 Análisis del archivo: ./dataMaps/review-New_York-20250209T110506Z-001/review-New_York/1.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        62676
# pics       145404
# resp       133162
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    99549
# 4    24298
# 3    10993
# 1    10986
# 2     4174
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 1990-12-31 00:00:00 - Hasta: 2021-09-08 02:08:59.373000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 38521
# Duplicados por gmap_id: 142159
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-New_York-20250209T110506Z-001/review-New_York/10.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        68231
# pics       143997
# resp       140275
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    85140
# 4    35879
# 3    16426
# 1     7267
# 2     5288
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2002-05-16 00:00:00 - Hasta: 2021-06-13 05:32:02.165000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 35678
# Duplicados por gmap_id: 148457
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-New_York-20250209T110506Z-001/review-New_York/11.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        56548
# pics       138219
# resp       135507
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    94634
# 4    31977
# 3    13232
# 1     5926
# 2     4231
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2002-05-31 00:00:00 - Hasta: 2021-06-11 18:52:16.427000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 36563
# Duplicados por gmap_id: 148232
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-New_York-20250209T110506Z-001/review-New_York/12.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        62155
# pics       144683
# resp       133974
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    94126
# 4    29079
# 3    13035
# 1     9177
# 2     4583
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 1990-12-31 00:00:00 - Hasta: 2021-06-08 03:07:44.170000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 34927
# Duplicados por gmap_id: 145567
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-New_York-20250209T110506Z-001/review-New_York/13.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        62793
# pics       144627
# resp       134505
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    93515
# 4    29678
# 3    13190
# 1     8979
# 2     4638
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2003-04-16 00:00:00 - Hasta: 2021-06-06 20:45:45.715000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 36276
# Duplicados por gmap_id: 145846
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-New_York-20250209T110506Z-001/review-New_York/14.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        63790
# pics       144724
# resp       135736
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    93636
# 4    30074
# 3    13110
# 1     8662
# 2     4518
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 1990-12-31 00:00:00 - Hasta: 2021-06-05 01:55:07.220000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 35488
# Duplicados por gmap_id: 146103
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-New_York-20250209T110506Z-001/review-New_York/15.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        62486
# pics       144407
# resp       134747
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    93563
# 4    30363
# 3    13089
# 1     8428
# 2     4557
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 1990-12-31 00:00:00 - Hasta: 2021-06-03 23:35:57.585000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 35522
# Duplicados por gmap_id: 146336
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-New_York-20250209T110506Z-001/review-New_York/16.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        63139
# pics       144463
# resp       134486
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    92750
# 4    30989
# 3    13618
# 1     8081
# 2     4562
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2003-04-02 00:00:00 - Hasta: 2021-06-02 20:58:59.583000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 35181
# Duplicados por gmap_id: 146545
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-New_York-20250209T110506Z-001/review-New_York/17.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        66509
# pics       144863
# resp       134995
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    92430
# 4    31840
# 3    13439
# 1     7854
# 2     4437
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 1990-12-31 00:00:00 - Hasta: 2021-06-02 00:14:34.342000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 33716
# Duplicados por gmap_id: 146952
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-New_York-20250209T110506Z-001/review-New_York/18.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        67414
# pics       144794
# resp       134806
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    91833
# 4    31791
# 3    13832
# 1     7845
# 2     4699
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 1990-12-31 00:00:00 - Hasta: 2021-06-01 05:20:19.793000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 33521
# Duplicados por gmap_id: 147073
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-New_York-20250209T110506Z-001/review-New_York/2.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        64195
# pics       145210
# resp       132560
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    98960
# 4    24972
# 3    11517
# 1    10291
# 2     4260
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 1990-12-31 00:00:00 - Hasta: 2021-08-14 17:46:14.564000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 33065
# Duplicados por gmap_id: 142728
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-New_York-20250209T110506Z-001/review-New_York/3.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        64682
# pics       145091
# resp       132506
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    98155
# 4    25848
# 3    11886
# 1     9777
# 2     4334
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 1990-12-31 00:00:00 - Hasta: 2021-08-01 23:47:05.541000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 33473
# Duplicados por gmap_id: 143366
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-New_York-20250209T110506Z-001/review-New_York/4.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        63238
# pics       145000
# resp       133672
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    96960
# 4    26704
# 3    12271
# 1     9737
# 2     4328
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 1990-12-31 00:00:00 - Hasta: 2021-07-02 04:33:43.928000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 34957
# Duplicados por gmap_id: 143990
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-New_York-20250209T110506Z-001/review-New_York/5.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        63797
# pics       144497
# resp       135729
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    94312
# 4    29358
# 3    12993
# 1     8843
# 2     4494
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 1990-12-31 00:00:00 - Hasta: 2021-06-25 07:33:33.202000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 34000
# Duplicados por gmap_id: 145293
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-New_York-20250209T110506Z-001/review-New_York/6.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        66081
# pics       144957
# resp       135807
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    91461
# 4    31896
# 3    13976
# 1     8058
# 2     4609
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 1990-12-31 00:00:00 - Hasta: 2021-06-21 03:36:35.401000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 34396
# Duplicados por gmap_id: 146931
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-New_York-20250209T110506Z-001/review-New_York/7.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        67812
# pics       144280
# resp       137767
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    88973
# 4    34318
# 3    14903
# 1     7156
# 2     4650
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 1990-12-31 00:00:00 - Hasta: 2021-06-19 06:21:59.384000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 36350
# Duplicados por gmap_id: 147795
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-New_York-20250209T110506Z-001/review-New_York/8.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        67881
# pics       144771
# resp       136951
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    88338
# 4    35067
# 3    14936
# 1     6866
# 2     4793
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 1990-12-31 00:00:00 - Hasta: 2021-06-17 02:09:09.907000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 36904
# Duplicados por gmap_id: 147869
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-New_York-20250209T110506Z-001/review-New_York/9.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        70166
# pics       144357
# resp       138818
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    87759
# 4    35201
# 3    15343
# 1     6931
# 2     4766
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 1990-12-31 00:00:00 - Hasta: 2021-06-15 03:16:43.153000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 33392
# Duplicados por gmap_id: 148299
#
# ✅ Análisis completado!

# %% [markdown]
# Aquí tienes la interpretación de los resultados:
#
# ### 1. **Valores nulos por columna**:
#    - **text**: **62,676** valores nulos, lo que sugiere que una gran parte de los registros no contiene texto.
#    - **pics**: **145,404** valores nulos, lo que indica que muchos registros no tienen imágenes.
#    - **resp**: **133,162** valores nulos, lo que significa que la mayoría de los registros no tienen respuestas asociadas.
#    - Las columnas `user_id`, `name`, `time`, `rating`, y `gmap_id` están completas sin valores nulos, lo cual es positivo para la integridad de los datos.
#
# ### 2. **Distribución de ratings**:
#    - **Rating 5** es el más frecuente con **99,549** registros, lo que podría indicar una tendencia general a calificar de manera positiva.
#    - **Rating 4** es el siguiente con **24,298** registros.
#    - **Rating 1** y **Rating 3** tienen **10,986** y **10,993** registros respectivamente, lo que muestra una distribución de calificaciones con un sesgo hacia las calificaciones positivas (5 y 4).
#    - **Rating 2** tiene **4,174** registros, que es el menos frecuente.
#
# **Conclusión**: La mayoría de las calificaciones en este dataset son positivas (4 y 5), lo que podría sugerir una tendencia de los usuarios a dejar buenas valoraciones.
#
# ### 3. **Rango de fechas en 'time'**:
#    - La fecha más antigua registrada es **1990-12-31**, lo que indica que los datos cubren un largo período de tiempo, desde 1990 hasta **2021-09-08**.
#    - Esto puede ser relevante para análisis a largo plazo de tendencias y comportamientos de los usuarios.
#
# ### 4. **Duplicados por gmap_id**:
#    - **148,299** registros tienen el mismo `gmap_id`, lo que sugiere que muchos registros pueden estar repetidos o que diferentes registros pueden estar asociados al mismo identificador de Google Maps.
#
# **Conclusión general**:
#    - Hay un alto porcentaje de valores nulos en las columnas `text`, `pics` y `resp`, lo que puede afectar el análisis de esos atributos.
#    - Las calificaciones son en su mayoría altas, lo que podría reflejar una tendencia de los usuarios a ser más positivos en sus valoraciones.
#    - Los duplicados en `gmap_id` deben investigarse, ya que podrían indicar registros redundantes o compartir el mismo identificador por razones que merecen revisión.

# %%
# Ruta de los archivos JSON
directory = "./dataMaps/review-Pennsylvania-20250209T110625Z-001/review-Pennsylvania/"  # Cambia esto a tu directorio con los archivos JSON
json_files = [os.path.join(directory, f) for f in os.listdir(directory) if f.endswith('.json')]


# Analizar los archivos JSON
for file in json_files:
    analyze_data(file)
    
# Lista para almacenar los DataFrames
all_data = []

# Cargar y combinar los datos de cada archivo JSON
for file in json_files:
    data = load_json(file)
    df = pd.DataFrame(data)
    all_data.append(df)

# Combinar todos los DataFrames en uno solo
combined_df = pd.concat(all_data, ignore_index=True)
combined_df.to_csv("./CSV/PN.csv", index=False)
# Out:
# 📌 Análisis del archivo: ./dataMaps/review-Pennsylvania-20250209T110625Z-001/review-Pennsylvania/1.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        63400
# pics       146302
# resp       130470
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    104452
# 4     22287
# 3      9887
# 1      9457
# 2      3917
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 1990-12-31 00:00:00 - Hasta: 2021-09-08 20:37:19.739000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 43731
# Duplicados por gmap_id: 142153
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Pennsylvania-20250209T110625Z-001/review-Pennsylvania/10.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        62684
# pics       146244
# resp       128636
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    97743
# 4    28290
# 3    12150
# 1     7547
# 2     4270
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2008-05-22 20:01:57.910000 - Hasta: 2021-06-03 17:27:08.654000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 42797
# Duplicados por gmap_id: 146525
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Pennsylvania-20250209T110625Z-001/review-Pennsylvania/11.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        64694
# pics       146307
# resp       130674
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    96486
# 4    28840
# 3    12567
# 1     7646
# 2     4461
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2006-02-18 00:00:00 - Hasta: 2021-06-02 11:20:15.317000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 42769
# Duplicados por gmap_id: 146748
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Pennsylvania-20250209T110625Z-001/review-Pennsylvania/12.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        66019
# pics       146269
# resp       132416
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    96594
# 4    29196
# 3    12556
# 1     7334
# 2     4320
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2008-07-23 16:50:28.333000 - Hasta: 2021-06-01 03:45:28.949000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 42148
# Duplicados por gmap_id: 147070
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Pennsylvania-20250209T110625Z-001/review-Pennsylvania/13.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        65927
# pics       146458
# resp       132888
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    96222
# 4    30068
# 3    12299
# 1     7096
# 2     4315
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2006-02-17 00:00:00 - Hasta: 2021-05-31 10:04:17.276000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 41811
# Duplicados por gmap_id: 147287
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Pennsylvania-20250209T110625Z-001/review-Pennsylvania/14.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        66839
# pics       146460
# resp       131649
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    94903
# 4    30453
# 3    13063
# 1     7140
# 2     4441
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2005-08-31 00:00:00 - Hasta: 2021-05-30 04:06:55.147000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 42171
# Duplicados por gmap_id: 147502
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Pennsylvania-20250209T110625Z-001/review-Pennsylvania/15.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        67270
# pics       146699
# resp       132217
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    94354
# 4    30785
# 3    13238
# 1     7150
# 2     4473
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2008-08-24 12:37:08.306000 - Hasta: 2021-05-29 12:25:26.936000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 43190
# Duplicados por gmap_id: 147719
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Pennsylvania-20250209T110625Z-001/review-Pennsylvania/16.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        66509
# pics       146467
# resp       130629
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    94028
# 4    30798
# 3    13203
# 1     7296
# 2     4675
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2006-02-19 00:00:00 - Hasta: 2021-05-28 18:53:26.123000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 43524
# Duplicados por gmap_id: 147707
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Pennsylvania-20250209T110625Z-001/review-Pennsylvania/2.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        64320
# pics       146354
# resp       129532
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    102776
# 4     23497
# 3     10502
# 1      9146
# 2      4079
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2004-09-26 00:00:00 - Hasta: 2021-08-07 19:07:43.841000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 41009
# Duplicados por gmap_id: 143172
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Pennsylvania-20250209T110625Z-001/review-Pennsylvania/3.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        62654
# pics       146231
# resp       129010
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    101249
# 4     24589
# 3     11024
# 1      8994
# 2      4144
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2008-01-07 15:36:15.740000 - Hasta: 2021-07-04 03:16:11.265000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 42076
# Duplicados por gmap_id: 143837
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Pennsylvania-20250209T110625Z-001/review-Pennsylvania/4.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        63751
# pics       146292
# resp       132376
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    96550
# 4    28889
# 3    12089
# 1     7971
# 2     4501
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2007-09-22 15:41:23.735000 - Hasta: 2021-06-23 05:33:32.806000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 41300
# Duplicados por gmap_id: 146143
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Pennsylvania-20250209T110625Z-001/review-Pennsylvania/5.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        68341
# pics       147016
# resp       136306
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    88020
# 4    32511
# 3    15622
# 1     8204
# 2     5643
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2006-02-26 00:00:00 - Hasta: 2021-06-19 02:02:30.034000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 43461
# Duplicados por gmap_id: 147741
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Pennsylvania-20250209T110625Z-001/review-Pennsylvania/6.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        68026
# pics       146299
# resp       135487
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    90775
# 4    34339
# 3    14452
# 1     6067
# 2     4367
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2006-02-17 00:00:00 - Hasta: 2021-06-16 13:34:40.731000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 44183
# Duplicados por gmap_id: 148333
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Pennsylvania-20250209T110625Z-001/review-Pennsylvania/7.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        65550
# pics       146238
# resp       126265
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    93884
# 4    31258
# 3    13185
# 1     7081
# 2     4592
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2006-02-17 00:00:00 - Hasta: 2021-06-13 16:32:15.513000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 43586
# Duplicados por gmap_id: 147102
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Pennsylvania-20250209T110625Z-001/review-Pennsylvania/8.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        62721
# pics       146291
# resp       129998
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    98398
# 4    27086
# 3    12018
# 1     8232
# 2     4266
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2006-02-17 00:00:00 - Hasta: 2021-06-07 23:06:14.384000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 42472
# Duplicados por gmap_id: 145694
#
# ✅ Análisis completado!
#
#
# 📌 Análisis del archivo: ./dataMaps/review-Pennsylvania-20250209T110625Z-001/review-Pennsylvania/9.json
#
# 🔍 Valores nulos por columna:
# user_id         0
# name            0
# time            0
# rating          0
# text        62681
# pics       146263
# resp       131336
# gmap_id         0
# dtype: int64
#
# 📊 Distribución de ratings:
# rating
# 5    97766
# 4    28146
# 3    11647
# 1     8051
# 2     4390
# Name: count, dtype: int64
#
# 🕒 Rango de fechas en 'time':
# Desde: 2004-03-12 00:00:00 - Hasta: 2021-06-05 18:16:59.889000
#
# 🛑 Duplicados en 'user_id' y 'gmap_id':
# Duplicados por usuario: 42925
# Duplicados por gmap_id: 146126
#
# ✅ Análisis completado!

# %% [markdown]
# ### Interpretación de los resultados:
#
# ### 1. **Valores nulos por columna**:
#    - **text**: **63,400** valores nulos. Muchos registros no contienen texto, lo que podría afectar los análisis basados en el contenido textual.
#    - **pics**: **146,302** valores nulos. Un gran número de registros no tiene fotos asociadas.
#    - **resp**: **130,470** valores nulos. La mayoría de los registros no tienen respuestas.
#    - Las columnas `user_id`, `name`, `time`, `rating`, y `gmap_id` están completas, lo que es positivo para la integridad de los datos.
#
# ### 2. **Distribución de ratings**:
#    - **Rating 5** es el valor más frecuente con **104,452** registros, lo que indica que la mayoría de los usuarios otorgan calificaciones muy altas.
#    - **Rating 4** sigue con **22,287** registros.
#    - **Rating 1** y **Rating 3** tienen **9,457** y **9,887** registros respectivamente, lo que sugiere que las calificaciones negativas o neutrales no son tan comunes.
#    - **Rating 2** tiene **3,917** registros, lo que es el valor menos frecuente.
#
# **Conclusión**: Al igual que en las respuestas anteriores, las calificaciones son predominantemente positivas (4 y 5), lo que podría indicar una tendencia de los usuarios a otorgar buenas valoraciones.
#
# ### 3. **Rango de fechas en 'time'**:
#    - El rango de fechas va desde **1990-12-31** hasta **2021-09-08**, lo que cubre un largo período de tiempo.
#    - Esto permite realizar análisis de tendencias a lo largo de varios años, observando posibles cambios en el comportamiento de los usuarios.
#
# ### 4. **Duplicados por gmap_id**:
#    - **146,126** registros tienen el mismo `gmap_id`, lo que sugiere que una gran cantidad de entradas pueden estar duplicadas o asociadas al mismo lugar, lo que merece ser investigado para evitar posibles errores o registros redundantes.
#
# **Conclusión general**:
#    - Existen muchos valores nulos en las columnas `text`, `pics` y `resp`, lo que podría afectar el análisis de estos atributos.
#    - Las calificaciones son en su mayoría positivas, lo que refleja una tendencia hacia valoraciones altas por parte de los usuarios.
#    - Los duplicados en `gmap_id` necesitan una revisión para entender si se trata de registros repetidos o de una asociación legítima entre entradas.

# %% [markdown]
# Cuando se encuentran valores nulos o faltantes en los datos, es importante decidir cómo manejarlos dependiendo del contexto y los objetivos del análisis. Aquí te doy algunas recomendaciones específicas para las columnas con valores nulos en tu caso:
#
# ### 1. **Columna `text` (63,400 valores nulos)**:
#    - **Relleno**: Si el `text` es relevante, podrías considerar rellenarlo con un valor genérico (por ejemplo, "Sin comentario") o utilizar técnicas de imputación (por ejemplo, rellenar con el texto más común o el valor más frecuente).
#
# ### 2. **Columna `pics` (146,302 valores nulos)**:
#    - **Eliminación**: Las fotos no son necesarias para el análisis, eliminar estas filas con valores nulos.
#
# ### 3. **Columna `resp` (130,470 valores nulos)**:
#    - **Eliminación**: Las respuestas no son cruciales para el análisis y la falta de ellas es masiva, vamos a eliminar estas filas.

# %%
# Ruta a la carpeta con los archivos CSV
directory = "./CSV"  # Cambia esto a la ruta de tu carpeta

# Recorrer todos los archivos en la carpeta
for filename in os.listdir(directory):
    if filename.endswith(".csv"):  # Solo archivos CSV
        file_path = os.path.join(directory, filename)
        
        # Leer el archivo CSV
        df = pd.read_csv(file_path)
        
        # Eliminar las columnas 'resp' y 'pics'
        if 'resp' in df.columns:
            df = df.drop(columns=['resp'])
        if 'pics' in df.columns:
            df = df.drop(columns=['pics'])
        
        # Guardar el archivo CSV modificado
        df.to_csv(file_path, index=False)  # Sobrescribir el archivo original

        print(f"Se han eliminado las columnas de {filename}")
# Out:
# Se han eliminado las columnas de California.csv
# Se han eliminado las columnas de Florida.csv
# Se han eliminado las columnas de Hawaii.csv
# Se han eliminado las columnas de NY.csv
# Se han eliminado las columnas de PN.csv

# %%
# Recorrer todos los archivos en la carpeta
for filename in os.listdir(directory):
    if filename.endswith(".csv"):  # Solo archivos CSV
        file_path = os.path.join(directory, filename)
        
        # Leer el archivo CSV
        df = pd.read_csv(file_path)
        
        # Imprimir las columnas de cada archivo
        print(f"Columnas en {filename}:")
        print(df.columns.tolist())
        print("-" * 40)
# Out:
# Columnas en California.csv:
# ['user_id', 'name', 'time', 'rating', 'text', 'gmap_id']
# ----------------------------------------
# Columnas en Florida.csv:
# ['user_id', 'name', 'time', 'rating', 'text', 'gmap_id']
# ----------------------------------------
# Columnas en Hawaii.csv:
# ['user_id', 'name', 'time', 'rating', 'text', 'gmap_id']
# ----------------------------------------
# Columnas en NY.csv:
# ['user_id', 'name', 'time', 'rating', 'text', 'gmap_id']
# ----------------------------------------
# Columnas en PN.csv:
# ['user_id', 'name', 'time', 'rating', 'text', 'gmap_id']
# ----------------------------------------

# %%
# Ruta de los archivos JSON
directory = "./dataMapsdataMaps/metadata-sitios"  # Cambia esto a tu directorio con los archivos JSON
json_files = [os.path.join(directory, f) for f in os.listdir(directory) if f.endswith('.json')]


# Analizar los archivos JSON
for file in json_files:
    analyze_data(file)
    
# Lista para almacenar los DataFrames
all_data = []

# Cargar y combinar los datos de cada archivo JSON
for file in json_files:
    data = load_json(file)
    df = pd.DataFrame(data)
    all_data.append(df)

# Combinar todos los DataFrames en uno solo
combined_df = pd.concat(all_data, ignore_index=True)
combined_df.to_csv("./CSV/PN.csv", index=False)
