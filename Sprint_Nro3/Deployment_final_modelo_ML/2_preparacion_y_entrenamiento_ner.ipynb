# %% [markdown]
# Como aún no tenemos datos etiquetados, lo primero que haremos es generar un pequeño conjunto de reseñas con etiquetas manuales.
# Carga el dataset de reseñas desde un archivo CSV (reviews_gm_cleaned.csv).
# Filtra las reseñas para eliminar aquellas cuyo texto es "No disponible".
# Selecciona aleatoriamente un conjunto de reseñas (actualmente el usuario está ajustando el número de muestras).
# Asigna etiquetas automáticamente a las reseñas según palabras clave detectadas en el texto. Las etiquetas posibles son:
# "food" (comida, restaurante, menú, etc.).
# "service" (servicio, atención al cliente, soporte, etc.).
# "price" (precio, costoso, barato, etc.).
# "location" (ubicación, vista, área, etc.).
# Guarda el resultado en un nuevo CSV (reviews_ner_manual.csv) para revisión manual

# %%
import spacy
from spacy.training import Example
import pandas as pd
import random
import os

# 1. Cargar datasets con encoding UTF-8
path_reviews = r"D:\Soy Henry\Proyecto Final\reviews_gm_cleaned.csv"
path_metadata = r"D:\Soy Henry\Proyecto Final\metadata_clean.csv"

df_reviews = pd.read_csv(path_reviews, encoding="utf-8")
df_metadata = pd.read_csv(path_metadata, encoding="utf-8")

# 2. Filtrar reseñas donde el texto no sea "No disponible" y eliminar nulos
df_reviews = df_reviews[df_reviews["text"].notna() & (df_reviews["text"] != "No disponible")]

# 3. Unir datasets usando gmap_id
df_merged = df_reviews.merge(df_metadata, on="gmap_id", how="left")

# 4. Seleccionar 5000 reseñas aleatorias para etiquetar
sample_reviews = df_merged.sample(5000, random_state=42)

# 5. Diccionario de categorías y palabras clave
keywords = {
    "FOOD": {"food", "restaurant", "eat", "menu", "drink", "dish", "delicious", "taco", "boba", "meal", "dining", "cuisine", "flavor"},
    "SERVICE": {"service", "staff", "customer", "attention", "help", "support", "reception", "checkout", "waiter", "friendly", "rude"},
    "PRICE": {"price", "cost", "cheap", "expensive", "affordable", "overpriced", "value", "deal", "worth"},
    "LOCATION": {"location", "place", "area", "view", "scenery", "spot", "attraction", "neighborhood", "convenient", "access"}
}

def assign_entities(text):
    """
    Asigna entidades basadas en la ocurrencia de palabras clave.
    Devuelve un diccionario con el formato:
    {"entities": [(start_index, end_index, "LABEL"), ...]}
    """
    entities = []
    lower_text = text.lower()
    
    for label, words in keywords.items():
        for word in words:
            start = 0
            while start < len(lower_text):
                start = lower_text.find(word, start)
                if start == -1:
                    break
                end = start + len(word)
                
                # Verificar si la nueva entidad se solapa con alguna existente
                overlapping = False
                for entity in entities:
                    if not (end <= entity[0] or start >= entity[1]):  # Si se solapan
                        overlapping = True
                        break
                
                if not overlapping:
                    entities.append((start, end, label))
                
                start = end
    
    return {"entities": entities}

# 6. Preparar datos de entrenamiento en formato SpaCy
train_data = []
for _, row in sample_reviews.iterrows():
    text = row["text"]
    entities = assign_entities(text)
    train_data.append((text, entities))

# 7. Cargar un modelo preentrenado de SpaCy
nlp = spacy.load("en_core_web_md")  # Cambia "es" por "en" si estás trabajando con inglés

# 8. Convertir datos a formato SpaCy
examples = []
for text, annotations in train_data:
    doc = nlp.make_doc(text)
    example = Example.from_dict(doc, annotations)
    examples.append(example)

# 9. Ajustar el modelo
optimizer = nlp.begin_training()
for epoch in range(10):  # Número de épocas
    random.shuffle(examples)
    for example in examples:
        nlp.update([example], drop=0.5, sgd=optimizer)

# 10. Guardar el modelo ajustado
output_model_path = r"D:\Soy Henry\Proyecto Final\yelp-google-reviews\Sprint_Nro3\Deployment_final_modelo_ML\adjusted_model"
os.makedirs(output_model_path, exist_ok=True)
nlp.to_disk(output_model_path)

print(f"✅ Modelo ajustado guardado en: {output_model_path}")
# Out:
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great service!!" with entities "[(2, 5, 'FOOD'), (6, 13, 'SERVICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "This place is cozy, food is delicious, bar serves ..." with entities "[(58, 63, 'FOOD'), (20, 24, 'FOOD'), (28, 37, 'FOO...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "This place is alright but the owners dont seem to ..." with entities "[(311, 315, 'SERVICE'), (5, 10, 'LOCATION')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Nice people better than goudy honda i buy my car h..." with entities "[(158, 162, 'PRICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "I love the market. It has a wonderful atmosphere. ..." with entities "[(134, 138, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The guys and gals at shoe palace know what’s up. W..." with entities "[(326, 329, 'FOOD'), (168, 172, 'SERVICE'), (367, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great spot with great personal service from the ow..." with entities "[(2, 5, 'FOOD'), (18, 21, 'FOOD'), (242, 245, 'FOO...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "hey foodie fam, are you craving for Chinese food? ..." with entities "[(4, 8, 'FOOD'), (44, 48, 'FOOD'), (243, 252, 'FOO...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The food taste great and is healthy." with entities "[(4, 8, 'FOOD'), (17, 20, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great prices and a place for gour money needs like..." with entities "[(2, 5, 'FOOD'), (6, 11, 'PRICE'), (19, 24, 'LOCAT...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Love there store, and also very helpful and friend..." with entities "[(55, 58, 'FOOD'), (32, 36, 'SERVICE'), (44, 52, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "I know this since 1987. Two excellent human being ..." with entities "[(60, 63, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great mexican food yummy!😙🙄🤗😇😋😊😉😆😄😃😎😍😀🤓😛👶👱👮🙇🙋💁🙅👸👩👨..." with entities "[(14, 18, 'FOOD'), (2, 5, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Much larger venue than it would seem like. Parking..." with entities "[(57, 60, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Unique and innovative products. Great customer ser..." with entities "[(34, 37, 'FOOD'), (38, 46, 'SERVICE'), (47, 54, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hundreds of variety at very competitive prices" with entities "[(40, 45, 'PRICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GREAT JOB THANK YOU FOR REVIVING MY PHONE." with entities "[(2, 5, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Whew!  The service, quantity, and quality is like ..." with entities "[(209, 213, 'FOOD'), (73, 83, 'FOOD'), (172, 175, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great location" with entities "[(2, 5, 'FOOD'), (6, 14, 'LOCATION')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "I've recorded at Prairie Sun multiple times since ..." with entities "[(107, 110, 'FOOD'), (233, 236, 'FOOD'), (208, 213...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great visit really good with kids 😃" with entities "[(2, 5, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Got a awesome deal a serta mattress. These guys ar..." with entities "[(54, 57, 'FOOD'), (14, 18, 'PRICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great food.. small restaurant" with entities "[(6, 10, 'FOOD'), (19, 29, 'FOOD'), (2, 5, 'FOOD')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "WE LOVE THIS PLACE - excellent  authentic fresh fo..." with entities "[(48, 52, 'FOOD'), (56, 59, 'FOOD'), (60, 65, 'PRI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Super friendly!!!I will use these guys again !!!" with entities "[(6, 14, 'SERVICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "(Translated by Google) The best champurrado I've h..." with entities "[(80, 84, 'FOOD'), (125, 129, 'FOOD'), (216, 220, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Terrible, incompetent, and haughty treatment of US..." with entities "[(37, 40, 'FOOD'), (53, 61, 'SERVICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great Experience! The Manager Richard and Associat..." with entities "[(2, 5, 'FOOD'), (78, 86, 'SERVICE'), (87, 94, 'SE...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Good, quick Starbucks, although often very busy. T..." with entities "[(69, 72, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "I worked out hard before bootcamp. So the bootcamp..." with entities "[(120, 123, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great selection of stores from Trader Joe's to Pie..." with entities "[(2, 5, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Pricey but tasty!" with entities "[(0, 5, 'PRICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great place. Very fair prices. Got my car back in ..." with entities "[(2, 5, 'FOOD'), (23, 28, 'PRICE'), (6, 11, 'LOCAT...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "This store has a little of everything! Make up, sh..." with entities "[(113, 116, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Food was unbelievably amazing , super clean and  g..." with entities "[(0, 4, 'FOOD'), (51, 54, 'FOOD'), (55, 63, 'SERVI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Mobile place there had great customer service... a..." with entities "[(25, 28, 'FOOD'), (29, 37, 'SERVICE'), (38, 45, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tim was my helper, he was solo today. Despite
# how ..." with entities "[(11, 15, 'SERVICE'), (93, 101, 'SERVICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great help!" with entities "[(2, 5, 'FOOD'), (6, 10, 'SERVICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Good meats, good price snd good people." with entities "[(6, 9, 'FOOD'), (17, 22, 'PRICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Best ice cream in the city! Perfect creaminess, no..." with entities "[(73, 79, 'FOOD'), (109, 114, 'SERVICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "First timer. Saying that I was very impressed with..." with entities "[(311, 315, 'FOOD'), (307, 310, 'FOOD'), (250, 255...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The owner has a comfortable exotic style that give..." with entities "[(125, 130, 'PRICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Took the family out to the museum and it's a great..." with entities "[(47, 50, 'FOOD'), (51, 55, 'PRICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Can't beat a professional florist! She was very fr..." with entities "[(7, 10, 'FOOD'), (72, 76, 'SERVICE'), (48, 56, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great tea every single time. Friendly staff." with entities "[(2, 5, 'FOOD'), (38, 43, 'SERVICE'), (29, 37, 'SE...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "I was referred to this company through my home war..." with entities "[(2280, 2283, 'FOOD'), (2299, 2303, 'SERVICE'), (3...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "This place is awesome, the price is definitely rig..." with entities "[(56, 59, 'FOOD'), (27, 32, 'PRICE'), (5, 10, 'LOC...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "What makes this shop different is they have every ..." with entities "[(94, 99, 'PRICE'), (50, 56, 'LOCATION'), (118, 12...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great spot! Super quick. Great service!! Very happ..." with entities "[(2, 5, 'FOOD'), (27, 30, 'FOOD'), (31, 38, 'SERVI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "It was great!" with entities "[(9, 12, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Wonderful people. Super quick job. Great product a..." with entities "[(37, 40, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great food, and decent outdoor seating." with entities "[(6, 10, 'FOOD'), (2, 5, 'FOOD'), (32, 35, 'FOOD')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Very helpful staff team. Wide range of stock in a ..." with entities "[(74, 77, 'FOOD'), (5, 9, 'SERVICE'), (13, 18, 'SE...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great deli, and meat department. We go here when w..." with entities "[(2, 5, 'FOOD'), (17, 20, 'FOOD'), (121, 124, 'FOO...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "This best buy has a lot of helpful employees. A on..." with entities "[(27, 31, 'SERVICE'), (182, 186, 'PRICE'), (303, 3...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "From the guacamole made at the table to the mole, ..." with entities "[(65, 74, 'FOOD'), (197, 206, 'FOOD'), (217, 221, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The environment is fun and light, all the workers ..." with entities "[(69, 73, 'SERVICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "One of the worst courts (bad light, no seats) in b..." with entities "[(40, 43, 'FOOD'), (53, 57, 'LOCATION')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great food and service as always.
#
# Drive thru traf..." with entities "[(6, 10, 'FOOD'), (2, 5, 'FOOD'), (15, 22, 'SERVIC...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great food!" with entities "[(6, 10, 'FOOD'), (2, 5, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great garbage and chili relleno burritos!" with entities "[(2, 5, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "👌👌👌👌👌👌Freaking great tacos!😋😋😋😋😋 recommended tripa..." with entities "[(21, 25, 'FOOD'), (51, 55, 'FOOD'), (17, 20, 'FOO...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "They are great" with entities "[(11, 14, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "I came in looking to buy a complete board and they..." with entities "[(64, 68, 'SERVICE'), (77, 82, 'SERVICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "We just left, ordered Chile relleno, torta, and ki..." with entities "[(136, 140, 'FOOD'), (186, 190, 'FOOD'), (152, 155...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "A classic jewel in roseville I miss Bernice the be..." with entities "[(349, 355, 'FOOD'), (337, 340, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Monday is the day to go. Happy hour all day. The b..." with entities "[(57, 60, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Clean restrooms great sound and picture" with entities "[(18, 21, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "They have the Best onion rings around! They use cr..." with entities "[(171, 176, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Over priced chains, nearly twice the price compare..." with entities "[(5, 10, 'PRICE'), (37, 42, 'PRICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "It was ok. Food is mediocre and priced a bit high ..." with entities "[(11, 15, 'FOOD'), (86, 92, 'FOOD'), (63, 70, 'SER...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great vibes, massive patio spacing (plenty of phys..." with entities "[(108, 112, 'FOOD'), (2, 5, 'FOOD'), (81, 86, 'SER...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Always a great experience specially for someone li..." with entities "[(11, 14, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Surely a place worth stopping by, the food is good..." with entities "[(38, 42, 'FOOD'), (106, 109, 'FOOD'), (15, 20, 'P...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great service and good food" with entities "[(23, 27, 'FOOD'), (2, 5, 'FOOD'), (6, 13, 'SERVIC...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great neighborhood it is safe it is nice great pla..." with entities "[(2, 5, 'FOOD'), (43, 46, 'FOOD'), (75, 78, 'FOOD'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "3 stars is for the 3 people I like there. The rest..." with entities "[(60, 64, 'SERVICE'), (548, 556, 'SERVICE'), (644,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "It's a nice shop to stop by...they have very cute ..." with entities "[(240, 244, 'SERVICE'), (200, 208, 'SERVICE'), (50...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Amy was amazing! Fast,neat & friendly! I definitel..." with entities "[(23, 26, 'FOOD'), (97, 100, 'FOOD'), (250, 253, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "It's Mc D's. Just like the rest. Good not great." with entities "[(44, 47, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Real professionals with great service." with entities "[(26, 29, 'FOOD'), (30, 37, 'SERVICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great breakfast" with entities "[(2, 5, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great place to have pure good fun." with entities "[(2, 5, 'FOOD'), (6, 11, 'LOCATION')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "(Translated by Google) Very small and with low pri..." with entities "[(47, 52, 'PRICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Fair prices, fair selection, nothing crazy. It's j..." with entities "[(5, 10, 'PRICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "5 Star house, great place." with entities "[(16, 19, 'FOOD'), (20, 25, 'LOCATION')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "friendly staff. clean. low prices. i didnt see the..." with entities "[(54, 58, 'FOOD'), (9, 14, 'SERVICE'), (0, 8, 'SER...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Secure, clean place with decent rental rates. Mark..." with entities "[(96, 100, 'SERVICE'), (14, 19, 'LOCATION'), (192,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "I get a lot of my Asian ingredients at Golden Bowl..." with entities "[(73, 77, 'SERVICE'), (56, 61, 'SERVICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Very helpful staff in this store. Thank you" with entities "[(5, 9, 'SERVICE'), (13, 18, 'SERVICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Clean and open. Great meat department." with entities "[(18, 21, 'FOOD'), (23, 26, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Slightly pricey, but great quality and portions." with entities "[(23, 26, 'FOOD'), (9, 14, 'PRICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The food wasn't bad and the prices were good." with entities "[(4, 8, 'FOOD'), (28, 33, 'PRICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great" with entities "[(2, 5, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Very good prices!" with entities "[(10, 15, 'PRICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great place. Been coming here for as long as they'..." with entities "[(2, 5, 'FOOD'), (6, 11, 'LOCATION')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great place to visit.  The whole family would love..." with entities "[(2, 5, 'FOOD'), (6, 11, 'LOCATION')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Could be improved... pricing is not transparent. P..." with entities "[(542, 545, 'FOOD'), (137, 145, 'SERVICE'), (491, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great people to do buisness with" with entities "[(2, 5, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great prices for your commercial tire needs. They ..." with entities "[(2, 5, 'FOOD'), (6, 11, 'PRICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Food good  but seated outside and the flies were t..." with entities "[(0, 4, 'FOOD'), (16, 19, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Ask for G. Great place and clean" with entities "[(13, 16, 'FOOD'), (17, 22, 'LOCATION')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great family sit down" with entities "[(2, 5, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "This place is a gold mine its so dam good and it i..." with entities "[(249, 255, 'FOOD'), (340, 344, 'FOOD'), (161, 164...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "I did not like the service, also they served my fr..." with entities "[(173, 178, 'FOOD'), (193, 198, 'FOOD'), (215, 219...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great small town store" with entities "[(2, 5, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# ...
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "This place dishonest I only give 2star" with entities "[(11, 15, 'FOOD'), (5, 10, 'LOCATION')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Cut your hair with Victoria she is great, especial..." with entities "[(37, 40, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Everyone was very Nice and helpful!" with entities "[(27, 31, 'SERVICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "park is great, clean and peacefull. Free concerts ..." with entities "[(10, 13, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great mexican bread" with entities "[(2, 5, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great Staff and super clean facility" with entities "[(2, 5, 'FOOD'), (6, 11, 'SERVICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Service was great but both times my order was wron..." with entities "[(14, 17, 'FOOD'), (0, 7, 'SERVICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Robyn(sp). In and out in a flash brand new LG G7 a..." with entities "[(92, 96, 'SERVICE'), (118, 122, 'PRICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "When this place gets busy it takes quite awhile to..." with entities "[(55, 59, 'SERVICE'), (10, 15, 'LOCATION')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Looking for food in the middle of the night in San..." with entities "[(444, 450, 'FOOD'), (12, 16, 'FOOD'), (295, 299, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Good places to eat none of these in the east coast..." with entities "[(15, 18, 'FOOD'), (5, 10, 'LOCATION')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Beautiful office.  Great for someone with anxiety ..." with entities "[(21, 24, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great tacos" with entities "[(6, 10, 'FOOD'), (2, 5, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Neighborhood beauty salon.  Good prices; clean and..." with entities "[(51, 59, 'SERVICE'), (33, 38, 'PRICE'), (0, 12, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Same reliable menu that you've known for years. Th..." with entities "[(175, 181, 'FOOD'), (67, 70, 'FOOD'), (14, 18, 'F...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Studio room itself was not too bad and I got all m..." with entities "[(678, 681, 'FOOD'), (1837, 1841, 'SERVICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Really cute ice cream shop with good ice cream and..." with entities "[(53, 56, 'FOOD'), (57, 65, 'SERVICE'), (66, 73, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great service and affordable prices" with entities "[(2, 5, 'FOOD'), (6, 13, 'SERVICE'), (18, 28, 'PRI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "What a nice and clean park in Filipino town!  Grea..." with entities "[(48, 51, 'FOOD'), (52, 56, 'LOCATION'), (189, 193...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great location, stiff drinks, friendly staff, indi..." with entities "[(22, 27, 'FOOD'), (74, 78, 'FOOD'), (2, 5, 'FOOD'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Best prices in town." with entities "[(5, 10, 'PRICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Was great the decades it was open....Now closed fo..." with entities "[(6, 9, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "AWESOME place..Great employees" with entities "[(17, 20, 'FOOD'), (8, 13, 'LOCATION')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Servers are nice, attentive and professional.
# The ..." with entities "[(311, 315, 'FOOD'), (447, 451, 'FOOD'), (203, 207...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Love love the drinks." with entities "[(14, 19, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great place to store stuff" with entities "[(2, 5, 'FOOD'), (6, 11, 'LOCATION')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "I own a 1997 Cadillac Eldorado ETC and the Cadilla..." with entities "[(271, 276, 'PRICE'), (52, 56, 'PRICE'), (170, 174...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great food big portions" with entities "[(6, 10, 'FOOD'), (2, 5, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "This place has the best bartenders and a great coc..." with entities "[(43, 46, 'FOOD'), (5, 10, 'LOCATION')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Always Treated With Respect, I Look Forward to Goi..." with entities "[(9, 12, 'FOOD')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Great day outing place with kids. The variety of a..." with entities "[(2, 5, 'FOOD'), (88, 91, 'FOOD'), (17, 22, 'LOCAT...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Friendly and helpful, they go out of their way to ..." with entities "[(13, 17, 'SERVICE'), (0, 8, 'SERVICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "We're NEVER disappointed with our visits to Rombau..." with entities "[(142, 150, 'SERVICE'), (192, 196, 'PRICE'), (105,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Talk about fast...Al is the best! I had a 4:00 p.m..." with entities "[(61, 65, 'LOCATION'), (346, 350, 'LOCATION')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Stephanie and her staff are the greatest, I love t..." with entities "[(34, 37, 'FOOD'), (18, 23, 'SERVICE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# ✅ Modelo ajustado guardado en: D:\Soy Henry\Proyecto Final\yelp-google-reviews\Sprint_Nro3\Deployment_final_modelo_ML\adjusted_model

# %%
import spacy

# Cargar el modelo entrenado desde la ruta proporcionada
output_model_path = r"D:\Soy Henry\Proyecto Final\yelp-google-reviews\Sprint_Nro3\Deployment_final_modelo_ML\adjusted_model"
nlp = spacy.load(output_model_path)

# Verificar las etiquetas de las entidades reconocidas por el modelo
print("Entidades que el modelo puede reconocer:")
for label in nlp.get_pipe("ner").labels:
    print(label)  # Imprime las etiquetas de entidades entrenadas

# También podemos verificar los componentes del pipeline
print("\nComponentes del pipeline:")
print(nlp.pipe_names)  # Imprime los nombres de los componentes del pipeline
# Out:
# Entidades que el modelo puede reconocer:
# CARDINAL
# DATE
# EVENT
# FAC
# FOOD
# GPE
# LANGUAGE
# LAW
# LOC
# LOCATION
# MONEY
# NORP
# ORDINAL
# ORG
# PERCENT
# PERSON
# PRICE
# PRODUCT
# QUANTITY
# SERVICE
# TIME
# WORK_OF_ART
#
# Componentes del pipeline:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
# Texto de prueba con ejemplos que incluyen diversas entidades
texto_prueba = """
The Apple store in New York has the latest iPhone models. The new iPhone 15 is priced at $999 and it comes in various colors. 
The customer service was excellent, and I had a great experience. The location of the store is very convenient near Central Park.
I also love the food at the nearby restaurant, it’s amazing. The store hosts a special event every month.
"""

# Procesar el texto con el modelo NER
doc = nlp(texto_prueba)

# Mostrar las entidades reconocidas
for ent in doc.ents:
    print(f"Texto: {ent.text}, Etiqueta: {ent.label_}")
# Out:
# Texto: customer, Etiqueta: SERVICE
# Texto: service, Etiqueta: SERVICE
# Texto: location, Etiqueta: LOCATION
# Texto: convenient, Etiqueta: LOCATION
# Texto: food, Etiqueta: FOOD
# Texto: restaurant, Etiqueta: FOOD
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\pipeline\attributeruler.py:149: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = self.matcher(doc, allow_missing=True, as_spans=False)
# c:\Users\calde\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)

# %%
# Ver las entidades reconocidas y su contexto
for ent in doc.ents:
    print(f"Texto: {ent.text}, Etiqueta: {ent.label_}, Start: {ent.start_char}, End: {ent.end_char}")

# Ver las palabras tokenizadas y sus partes del discurso (POS)
for token in doc:
    print(f"Token: {token.text}, POS: {token.pos_}, Tag: {token.tag_}")
# Out:
# Texto: customer, Etiqueta: SERVICE, Start: 132, End: 140
# Texto: service, Etiqueta: SERVICE, Start: 141, End: 148
# Texto: location, Etiqueta: LOCATION, Start: 198, End: 206
# Texto: convenient, Etiqueta: LOCATION, Start: 228, End: 238
# Texto: food, Etiqueta: FOOD, Start: 274, End: 278
# Texto: restaurant, Etiqueta: FOOD, Start: 293, End: 303
# Token:
# , POS: , Tag: $
# Token: The, POS: , Tag: $
# Token: Apple, POS: , Tag: $
# Token: store, POS: , Tag: $
# Token: in, POS: , Tag: $
# Token: New, POS: , Tag: $
# Token: York, POS: , Tag: $
# Token: has, POS: , Tag: $
# Token: the, POS: , Tag: $
# Token: latest, POS: , Tag: $
# Token: iPhone, POS: , Tag: $
# Token: models, POS: , Tag: $
# Token: ., POS: , Tag: $
# Token: The, POS: , Tag: $
# Token: new, POS: , Tag: $
# Token: iPhone, POS: , Tag: $
# Token: 15, POS: , Tag: $
# Token: is, POS: , Tag: $
# Token: priced, POS: , Tag: $
# Token: at, POS: , Tag: $
# Token: $, POS: , Tag: $
# Token: 999, POS: , Tag: $
# Token: and, POS: , Tag: $
# Token: it, POS: , Tag: $
# Token: comes, POS: , Tag: $
# Token: in, POS: , Tag: $
# Token: various, POS: , Tag: $
# Token: colors, POS: , Tag: $
# Token: ., POS: , Tag: $
# Token:
# , POS: , Tag: $
# Token: The, POS: , Tag: $
# Token: customer, POS: , Tag: $
# Token: service, POS: , Tag: $
# Token: was, POS: , Tag: $
# Token: excellent, POS: , Tag: $
# Token: ,, POS: , Tag: $
# Token: and, POS: , Tag: $
# Token: I, POS: , Tag: $
# Token: had, POS: , Tag: $
# Token: a, POS: , Tag: $
# Token: great, POS: , Tag: $
# Token: experience, POS: , Tag: $
# Token: ., POS: , Tag: $
# Token: The, POS: , Tag: $
# Token: location, POS: , Tag: $
# Token: of, POS: , Tag: $
# Token: the, POS: , Tag: $
# Token: store, POS: , Tag: $
# Token: is, POS: , Tag: $
# Token: very, POS: , Tag: $
# Token: convenient, POS: , Tag: $
# Token: near, POS: , Tag: $
# Token: Central, POS: , Tag: $
# Token: Park, POS: , Tag: $
# Token: ., POS: , Tag: $
# Token:
# , POS: , Tag: $
# Token: I, POS: , Tag: $
# Token: also, POS: , Tag: $
# Token: love, POS: , Tag: $
# Token: the, POS: , Tag: $
# Token: food, POS: , Tag: $
# Token: at, POS: , Tag: $
# Token: the, POS: , Tag: $
# Token: nearby, POS: , Tag: $
# Token: restaurant, POS: , Tag: $
# Token: ,, POS: , Tag: $
# Token: it, POS: , Tag: $
# Token: ’s, POS: , Tag: $
# Token: amazing, POS: , Tag: $
# Token: ., POS: , Tag: $
# Token: The, POS: , Tag: $
# Token: store, POS: , Tag: $
# Token: hosts, POS: , Tag: $
# Token: a, POS: , Tag: $
# Token: special, POS: , Tag: $
# Token: event, POS: , Tag: $
# Token: every, POS: , Tag: $
# Token: month, POS: , Tag: $
# Token: ., POS: , Tag: $
# Token:
# , POS: , Tag: $
