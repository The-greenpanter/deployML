# %%
import pandas as pd
import json

#  Cargar el CSV con pandas
ruta_csv = "D:/Soy Henry/Proyecto Final/metadata.csv"  # Ajusta la ruta real
df = pd.read_csv(ruta_csv)

#  Manejo de valores nulos
df.fillna({
    'description': 'Desconocido',  # Rellenar descripciones vacías
    'address': 'Sin dirección'  # Rellenar direcciones vacías
}, inplace=True)

#  Convertir columnas numéricas al tipo correcto
df["latitude"] = pd.to_numeric(df["latitude"], errors="coerce")
df["longitude"] = pd.to_numeric(df["longitude"], errors="coerce")
df["avg_rating"] = pd.to_numeric(df["avg_rating"], errors="coerce")
df["num_of_reviews"] = pd.to_numeric(df["num_of_reviews"], errors="coerce", downcast="integer")

#  Transformar 'category' de JSON-string a CSV-compatible
def clean_json_column(json_str):
    try:
        return ",".join(json.loads(json_str.replace("'", '"'))) if pd.notna(json_str) else ""
    except json.JSONDecodeError:
        return ""

df["category"] = df["category"].apply(clean_json_column)

#  Limpiar y mejorar 'hours'
df["hours"] = df["hours"].astype(str).str.replace("â€“", "-", regex=False)

# Parsear JSON en 'hours' y 'MISC'
def parse_json_safe(json_str):
    try:
        return json.dumps(json.loads(json_str.replace("'", '"'))) if pd.notna(json_str) else "{}"
    except json.JSONDecodeError:
        return "{}"

df["MISC"] = df["MISC"].apply(parse_json_safe)

#  Guardar en **CSV optimizado para Power BI**
ruta_salida_csv = "D:/metadata_clean.csv"
df.to_csv(ruta_salida_csv, index=False, encoding="utf-8")

#  Contar valores nulos
print(df.isnull().sum())

#  Filtrar negocios por categoría (ejemplo: farmacias)
print(df[df["category"].str.contains("Pharmacy", na=False)])

#  Estadísticas básicas de ratings
print(df["avg_rating"].describe())

print("✅ ETL finalizado con pandas. CSV listo para Power BI.")
# Out:
# name                     38
# address                   0
# gmap_id                   0
# description               0
# latitude                  0
# longitude                 0
# category                  0
# avg_rating                0
# num_of_reviews            0
# price               1741198
# hours                     0
# MISC                      0
# state                465999
# relative_results     182620
# url                       0
# dtype: int64
#                                                       name  \
# 0                                          Porter Pharmacy
# 35                                        Walmart Pharmacy
# 106                                        Kroger Pharmacy
# 147                               My Express Care Pharmacy
# 155                                     Walgreens Pharmacy
# ...                                                    ...
# 1922846  Lakewood Apothecary and Natural Health Center Inc
# 1922880                                       CVS Pharmacy
# 1923196                              Advance Care Pharmacy
# 1923463            Harness Health Pharmacy - DePaul Atrium
# 1923844                                Fred Meyer Pharmacy
#
#                                                    address  \
# 0        Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 35        Walmart Pharmacy, 12220 FM 423, Frisco, TX 75033
# 106      Kroger Pharmacy, 120 S Memorial Dr, New Castle...
# 147      My Express Care Pharmacy, 4453 Crain Hwy, Whit...
# 155      Walgreens Pharmacy, 124 E North St, Kendallvil...
# ...                                                    ...
# 1922846  Lakewood Apothecary and Natural Health Center ...
# 1922880  CVS Pharmacy, 4531 Troost Ave, Kansas City, MO...
# 1923196  Advance Care Pharmacy, 24822 John R Rd, Hazel ...
# 1923463  Harness Health Pharmacy - DePaul Atrium, 155 K...
# 1923844  Fred Meyer Pharmacy, 4701 US-101, Florence, OR...
#
#                                        gmap_id  \
# 0        0x88f16e41928ff687:0x883dad4fd048e8f8
# 35       0x864c3998b8d8dc83:0x57ffabe1e2322320
# 106      0x8815330a1e6689a3:0xe58dda0d48d024cc
# 147      0x89b7a76096bdad0b:0x66e4be0af3dc1720
# 155      0x881614ce7c13acbb:0x5c7b18bbf6ec4f7e
# ...                                        ...
# 1922846  0x89d2aba57d10bb89:0xab332e455d8a5be1
# 1922880  0x87c0eff2ac8030b3:0x34ab71bbff048d15
# 1923196  0x8824cfb93c613a53:0xd8efd990183d8506
# 1923463  0x152e4b3d6cc5ede1:0x4c771e18e8afdc8d
# 1923844  0x54c1805cd65e0551:0x81baaf5439376f61
#
#                                                description   latitude  \
# 0                                              Desconocido  32.388300
# 35                                             Desconocido  33.179867
# 106                                            Desconocido  39.929957
# 147                                            Desconocido  38.590861
# 155      Department of the Walgreens chain providing pr...  41.451860
# ...                                                    ...        ...
# 1922846                                        Desconocido  42.102023
# 1922880                                        Desconocido  39.044255
# 1923196                                        Desconocido  42.475082
# 1923463                                        Desconocido  36.898013
# 1923844                                        Desconocido  44.007717
#
#           longitude                                           category  \
# 0        -83.357100                                           Pharmacy
# 35       -96.883691  Pharmacy,Drug store,Medical supply store,Vitam...
# 106      -85.379539                                           Pharmacy
# 147      -76.942975                                           Pharmacy
# 155      -85.266676                                           Pharmacy
# ...             ...                                                ...
# 1922846  -79.326376               Vitamin & supplements store,Pharmacy
# 1922880  -94.572357                                           Pharmacy
# 1923196  -83.104117                                           Pharmacy
# 1923463  -76.282554            Pharmacy,Drug store,Hospital department
# 1923844 -124.103153                                           Pharmacy
#
#          avg_rating  num_of_reviews price  \
# 0               4.9              16   NaN
# 35              3.3              24     $
# 106             4.0               6    $$
# 147             4.6              32   NaN
# 155             4.2               5    $$
# ...             ...             ...   ...
# 1922846         4.8              35   NaN
# 1922880         4.4               5   NaN
# 1923196         4.7              18   NaN
# 1923463         4.4               4   NaN
# 1923844         3.2               8   NaN
#
#                                                      hours  \
# 0        [['Friday', '8AM–6PM'], ['Saturday', '8AM–12PM...
# 35       [['Thursday', '9AM–9PM'], ['Friday', '9AM–9PM'...
# 106      [['Thursday', '9AM–8PM'], ['Friday', '9AM–8PM'...
# 147      [['Thursday', '9AM–5PM'], ['Friday', '9AM–5PM'...
# 155      [['Thursday', '8AM–1:30PM'], ['Friday', '8AM–1...
# ...                                                    ...
# 1922846  [['Saturday', '9AM–2PM'], ['Sunday', 'Closed']...
# 1922880  [['Saturday', '9AM–6PM'], ['Sunday', '10AM–6PM...
# 1923196  [['Saturday', '12–3PM'], ['Sunday', 'Closed'],...
# 1923463  [['Saturday', 'Closed'], ['Sunday', 'Closed'],...
# 1923844  [['Saturday', '9AM–6PM'], ['Sunday', '11AM–6PM...
#
#                                                       MISC  \
# 0        {"Service options": ["In-store shopping", "Sam...
# 35       {"Service options": ["Curbside pickup", "In-st...
# 106      {"Service options": ["Curbside pickup", "In-st...
# 147      {"Service options": ["In-store shopping"], "Ac...
# 155      {"Service options": ["Curbside pickup", "Drive...
# ...                                                    ...
# 1922846  {"Service options": ["In-store pickup", "In-st...
# 1922880  {"Service options": ["Delivery", "In-store pic...
# 1923196  {"Service options": ["Delivery", "Drive-throug...
# 1923463  {"Service options": ["Online care", "In-store ...
# 1923844  {"Service options": ["Curbside pickup", "In-st...
#
#                                       state  \
# 0                         Open ⋅ Closes 6PM
# 35                        Open ⋅ Closes 9PM
# 106                       Open ⋅ Closes 8PM
# 147                       Open ⋅ Closes 5PM
# 155      Closes soon ⋅ 1:30PM ⋅ Reopens 2PM
# ...                                     ...
# 1922846              Closed ⋅ Opens 9AM Mon
# 1922880                   Open ⋅ Closes 6PM
# 1923196  Closes soon ⋅ 3PM ⋅ Opens 10AM Mon
# 1923463              Closed ⋅ Opens 9AM Mon
# 1923844                   Open ⋅ Closes 6PM
#
#                                           relative_results  \
# 0        ['0x88f16e41929435cf:0x5b2532a2885e9ef6', '0x8...
# 35       ['0x864c3999b29e291f:0x2d364c05e88eec13', '0x8...
# 106      ['0x881533760dba1255:0xdeb517598dd2f2f3', '0x8...
# 147      ['0x89b7a0e957a2682b:0x58e2941121a6aa96', '0x8...
# 155      ['0x881614cd49e4fa33:0x2d507c24ff4f1c74', '0x8...
# ...                                                    ...
# 1922846  ['0x89d2a9e005613e83:0x33f53227eca8babe', '0x8...
# 1922880  ['0x87c0ef92997315ed:0x9398e075c496676e', '0x8...
# 1923196  ['0x8824cfccbea7555b:0x88a345d1944994d8', '0x8...
# 1923463  ['0x89ba99dcb3e56bbb:0x81dab866277f5b9c', '0x8...
# 1923844  ['0x54c1801226d29b6b:0x79d1d726a5a60822', '0x5...
#
#                                                        url
# 0        https://www.google.com/maps/place//data=!4m2!3...
# 35       https://www.google.com/maps/place//data=!4m2!3...
# 106      https://www.google.com/maps/place//data=!4m2!3...
# 147      https://www.google.com/maps/place//data=!4m2!3...
# 155      https://www.google.com/maps/place//data=!4m2!3...
# ...                                                    ...
# 1922846  https://www.google.com/maps/place//data=!4m2!3...
# 1922880  https://www.google.com/maps/place//data=!4m2!3...
# 1923196  https://www.google.com/maps/place//data=!4m2!3...
# 1923463  https://www.google.com/maps/place//data=!4m2!3...
# 1923844  https://www.google.com/maps/place//data=!4m2!3...
#
# [12252 rows x 15 columns]
# count    1.925007e+06
# mean     4.302853e+00
# std      7.051855e-01
# min      1.000000e+00
# 25%      4.000000e+00
# 50%      4.500000e+00
# 75%      4.800000e+00
# max      5.000000e+00
# Name: avg_rating, dtype: float64
# ✅ ETL finalizado con pandas. CSV listo para Power BI.

# %% [markdown]
# 🔹 Resumen de Cambios
# ✅ Manejo de valores nulos:
#
# Se rellenaron valores nulos en description con "Desconocido".
# Se rellenaron valores nulos en address con "Sin dirección".
# ✅ Conversión de tipos de datos:
#
# latitude, longitude, avg_rating y num_of_reviews fueron convertidos a float o integer según corresponda.
# num_of_reviews se optimizó con downcast="integer" para reducir uso de memoria.
# ✅ Transformaciones y limpieza de datos:
#
# Se convirtió la columna category de JSON-string a formato compatible con CSV.
# Se limpiaron caracteres no deseados en hours (por ejemplo, "â€“" → "-").
# Se manejó el JSON en MISC, asegurando un formato válido.
# ✅ Optimización para Power BI:
#
# Se guardó el archivo transformado como metadata_clean.csv en formato UTF-8.
# ✅ Análisis de calidad de datos:
#
# Se realizó un conteo de valores nulos.
# Se filtraron negocios por categoría específica (ejemplo: farmacias).
# Se generaron estadísticas básicas de ratings (avg_rating).
# Principales Mejoras:
# 🔹 Se asegura consistencia y compatibilidad de datos para análisis en Power BI.
# 🔹 Reducción de errores en JSON y caracteres extraños.
# 🔹 Se mejoró la eficiencia con tipos de datos correctos y optimización de memoria.
# 🔹 Código más robusto y reutilizable para futuras transformaciones.
#
# ✅ ETL Google Maps finalizado con éxito.
