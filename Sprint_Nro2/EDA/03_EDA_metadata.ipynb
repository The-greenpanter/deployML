# %% [markdown]
# <h1>Analisis de la calidad de los datos de google</h1>

# %% [markdown]
# <h3>Importamos librerias a usar.</h3>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %% [markdown]
# <h4>Disponemos la ruta donde estara el archivo</h4>

# %%
folder_path = r'C:\Users\EFRAIN LINARES\Desktop\Proyecto Final\Google\metadata.csv.xls'

# %% [markdown]
# <h4>Creamos el DataFrame con los datos</h4>

# %%
df = pd.read_csv(folder_path)

# %%
df
# Out:
#                                       name  \
# 0                          Porter Pharmacy
# 1                             City Textile
# 2                             San Soo Dang
# 3                             Nova Fabrics
# 4                         Nobel Textile Co
# ...                                    ...
# 1925002     The Green Room Of Libertyville
# 1925003           Klein Brothers Packaging
# 1925004               Profiles Hair Design
# 1925005                     Arizona LINE-X
# 1925006  US Forest Services Ranger Station
#
#                                                    address  \
# 0        Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1        City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2        San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 3        Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 4        Nobel Textile Co, 719 E 9th St, Los Angeles, C...
# ...                                                    ...
# 1925002  The Green Room Of Libertyville, 624 Milwaukee ...
# 1925003  Klein Brothers Packaging, 1515 S Fresno Ave, S...
# 1925004  Profiles Hair Design, 522 N Federal Blvd, Rive...
# 1925005  Arizona LINE-X, 21242 N Black Canyon Hwy #A, P...
# 1925006  US Forest Services Ranger Station, 333 E Main ...
#
#                                        gmap_id  \
# 0        0x88f16e41928ff687:0x883dad4fd048e8f8
# 1        0x80c2c98c0e3c16fd:0x29ec8a728764fdf9
# 2        0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 3         0x80c2c89923b27a41:0x32041559418d447
# 4        0x80c2c632f933b073:0xc31785961fe826a6
# ...                                        ...
# 1925002  0x880f96c84b0ef57b:0xe75b67b15a2cfdad
# 1925003  0x80901260b5987b39:0x8a5028c253e7bee6
# 1925004  0x8758dd1e2533c991:0x5f6d112918f07dba
# 1925005  0x872b6f6f24aea445:0x22df9e5dd01e67ba
# 1925006  0x875901f1fbd58357:0xed5174d5b088430c
#
#                                                description   latitude  \
# 0                                                      NaN  32.388300
# 1                                                      NaN  34.018891
# 2                                                      NaN  34.058092
# 3                                                      NaN  34.023669
# 4                                                      NaN  34.036694
# ...                                                    ...        ...
# 1925002  Innovative, globally inspired dishes are paire...  42.289450
# 1925003                                                NaN  37.934318
# 1925004                                                NaN  43.029664
# 1925005                                                NaN  33.680066
# 1925006                                                NaN  42.829621
#
#           longitude                                           category  \
# 0        -83.357100                                       ['Pharmacy']
# 1       -118.215290                               ['Textile exporter']
# 2       -118.292130                              ['Korean restaurant']
# 3       -118.232930                                   ['Fabric store']
# 4       -118.249421                                   ['Fabric store']
# ...             ...                                                ...
# 1925002  -87.954386                              ['Restaurant', 'Bar']
# 1925003 -121.313102                               ['Trucking company']
# 1925004 -108.380849                     ['Beauty salon', 'Hair salon']
# 1925005 -112.113367  ['Truck accessories store', 'Powder coating se...
# 1925006 -108.723720                                     ['Campground']
#
#          avg_rating  num_of_reviews price  \
# 0               4.9              16   NaN
# 1               4.5               6   NaN
# 2               4.4              18   NaN
# 3               3.3               6   NaN
# 4               4.3               7   NaN
# ...             ...             ...   ...
# 1925002         4.6             228    $$
# 1925003         4.2               3   NaN
# 1925004         4.7              76   NaN
# 1925005         4.6              24   NaN
# 1925006         4.2              24   NaN
#
#                                                      hours  \
# 0        [['Friday', '8AM–6PM'], ['Saturday', '8AM–12PM...
# 1                                                      NaN
# 2        [['Thursday', '6:30AM–6PM'], ['Friday', '6:30A...
# 3        [['Thursday', '9AM–5PM'], ['Friday', '9AM–5PM'...
# 4        [['Thursday', '9AM–5PM'], ['Friday', '9AM–5PM'...
# ...                                                    ...
# 1925002  [['Saturday', '4:30–9PM'], ['Sunday', 'Closed'...
# 1925003  [['Saturday', '10AM–1PM'], ['Sunday', 'Closed'...
# 1925004  [['Saturday', '9AM–4PM'], ['Sunday', 'Closed']...
# 1925005  [['Saturday', 'Closed'], ['Sunday', 'Closed'],...
# 1925006                                                NaN
#
#                                                       MISC  \
# 0        {'Service options': ['In-store shopping', 'Sam...
# 1                                                      NaN
# 2        {'Service options': ['Takeout', 'Dine-in', 'De...
# 3        {'Service options': ['In-store shopping'], 'Pa...
# 4                 {'Service options': ['In-store pickup']}
# ...                                                    ...
# 1925002  {'Service options': ['Curbside pickup', 'No-co...
# 1925003                                                NaN
# 1925004  {'Accessibility': ['Wheelchair accessible entr...
# 1925005  {'Service options': ['In-store shopping'], 'Pa...
# 1925006  {'Accessibility': ['Wheelchair accessible entr...
#
#                           state  \
# 0             Open ⋅ Closes 6PM
# 1                      Open now
# 2             Open ⋅ Closes 6PM
# 3             Open ⋅ Closes 5PM
# 4             Open ⋅ Closes 5PM
# ...                         ...
# 1925002   Closed ⋅ Opens 4:30PM
# 1925003       Open ⋅ Closes 1PM
# 1925004       Open ⋅ Closes 4PM
# 1925005  Closed ⋅ Opens 8AM Mon
# 1925006                     NaN
#
#                                           relative_results  \
# 0        ['0x88f16e41929435cf:0x5b2532a2885e9ef6', '0x8...
# 1        ['0x80c2c624136ea88b:0xb0315367ed448771', '0x8...
# 2        ['0x80c2c78249aba68f:0x35bf16ce61be751d', '0x8...
# 3        ['0x80c2c8811477253f:0x23a8a492df1918f7', '0x8...
# 4        ['0x80c2c62c496083d1:0xdefa11317fe870a1', '0x8...
# ...                                                    ...
# 1925002  ['0x880f96c848329bd5:0x5a6609c274091c81', '0x8...
# 1925003  ['0x80900c2bd9b41a37:0x5de883f3a0746a61', '0x8...
# 1925004  ['0x8758dd1ffba87d8f:0xf211a1ebf7297000', '0x8...
# 1925005  ['0x872b6f9d1b41ad95:0x94a335fc923f0987', '0x8...
# 1925006  ['0x8758fe025f4f7419:0xc98c1e92db448cb8', '0x8...
#
#                                                        url
# 0        https://www.google.com/maps/place//data=!4m2!3...
# 1        https://www.google.com/maps/place//data=!4m2!3...
# 2        https://www.google.com/maps/place//data=!4m2!3...
# 3        https://www.google.com/maps/place//data=!4m2!3...
# 4        https://www.google.com/maps/place//data=!4m2!3...
# ...                                                    ...
# 1925002  https://www.google.com/maps/place//data=!4m2!3...
# 1925003  https://www.google.com/maps/place//data=!4m2!3...
# 1925004  https://www.google.com/maps/place//data=!4m2!3...
# 1925005  https://www.google.com/maps/place//data=!4m2!3...
# 1925006  https://www.google.com/maps/place//data=!4m2!3...
#
# [1925007 rows x 15 columns]

# %% [markdown]
# <h4>Visualizamos el tipo de datos y cuantas columnas tiene el DataFrame.</h4>

# %%
# Visualizar columnas
df.columns
# Out:
# Index(['name', 'address', 'gmap_id', 'description', 'latitude', 'longitude',
#        'category', 'avg_rating', 'num_of_reviews', 'price', 'hours', 'MISC',
#        'state', 'relative_results', 'url'],
#       dtype='object')

# %%
df_business = df

# %%
# Verificar el tipo de datos del DataFrame
print(df_business.dtypes)
# Out:
# name                 object
# address              object
# gmap_id              object
# description          object
# latitude            float64
# longitude           float64
# category             object
# avg_rating          float64
# num_of_reviews        int64
# price                object
# hours                object
# MISC                 object
# state                object
# relative_results     object
# url                  object
# dtype: object

# %% [markdown]
# <h4>Verificamos valores nulos y sacamos el porcentaje de los mismos</h4>

# %%
# Verificamos los valores nulos del dataFrame

valores_nulos = df_business.isnull().sum()
print("Valores nulos por columna:")
print(valores_nulos) #Valores nulos
# Out:
# Valores nulos por columna:
# name                     38
# address               48944
# gmap_id                   0
# description         1755238
# latitude                  0
# longitude                 0
# category              10624
# avg_rating                0
# num_of_reviews            0
# price               1741198
# hours                491188
# MISC                 427783
# state                465999
# relative_results     182620
# url                       0
# dtype: int64

# %%
# Verificamos el porcentaje de los valores nulos

porcentaje_nulos = (df_business.isnull().sum() / len(df_business)) * 100
print("Porcentaje de los valores nulos por columna:")

print(porcentaje_nulos)
# Out:
# Porcentaje de los valores nulos por columna:
# name                 0.001974
# address              2.542536
# gmap_id              0.000000
# description         91.180863
# latitude             0.000000
# longitude            0.000000
# category             0.551894
# avg_rating           0.000000
# num_of_reviews       0.000000
# price               90.451515
# hours               25.516167
# MISC                22.222413
# state               24.207652
# relative_results     9.486719
# url                  0.000000
# dtype: float64

# %% [markdown]
# <b>Podemos observar una gran cantidad de valores faltantes y nulos en las columnas “description” y “price”. Los datos faltantes superan el 90% en ambos casos, por lo que su infomación es, prima facie, irrelevante para identificar posibles insights.</b>

# %%
# Calcular la cantidad de valores nulos por columna en df_business_google
cantidad_nulos_google = df_business.isnull().sum()

# Filtrar solo las columnas que tienen nulos
cantidad_nulos_google = cantidad_nulos_google[cantidad_nulos_google > 0]

# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
ax = cantidad_nulos_google.plot(kind='bar', color='blue')

# Personalizar el gráfico
plt.title('Cantidad de valores nulos por columna en df_business', fontsize=14)
plt.xlabel('Columnas')
plt.ylabel('Cantidad de valores nulos (Escala log)')
plt.xticks(rotation=45, ha='right')

# Añadir etiquetas con los valores encima de cada barra
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())} Nulos', (p.get_x() * 1.005, p.get_height() * 1.1))

# Ajustar la escala si las diferencias son grandes
ax.set_yscale('log')  # Escala logarítmica para mejorar la visualización

plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# <b>Este grafico muestra la cantidad de nulos representada en escala logaritmica y encima de cada barra podemos visualizar la cantidad real de los mismos.</b>

# %% [markdown]
# <h4>Buscamos columnas duplicadas</h4>

# %%
# Verificar si hay columnas duplicadas en el DataFrame
duplicated_columns = df_business.columns[df_business.columns.duplicated()]
print(f"Columnas duplicadas: {duplicated_columns}")
# Out:
# Columnas duplicadas: Index([], dtype='object')

# %% [markdown]
# <h4>Buscamos Filas duplicadas</h4>

# %%
# Convertir todas las columnas de tipo 'object' (incluyendo listas y diccionarios) a cadenas de texto
for col in df_business.columns:
    if df_business[col].dtype == 'object':
        df_business[col] = df_business[col].apply(lambda x: str(x) if isinstance(x, (list, dict)) else x)

# Encontrar las filas duplicadas
filas_duplicadas = df_business[df_business.duplicated(keep=False)]  

# Numero de filas duplicadas
print(f"Número total de filas duplicadas: {df_business.duplicated().sum()}")
# Out:
# Número total de filas duplicadas: 26579

# %% [markdown]
# <h4>Graficamos las filas duplicadas en comparación al total de los datos duplicados</h4>

# %%
# Calcular la cantidad de filas duplicadas
total_filas = len(df_business)
filas_duplicadas = df_business.duplicated().sum()
filas_unicas = total_filas - filas_duplicadas

# Crear los datos para el gráfico
datos_duplicados = [filas_unicas, filas_duplicadas]
etiquetas = ['Filas Únicas', 'Filas Duplicadas']
colores = ['red', 'orange']

# Crear el gráfico circular
plt.figure(figsize=(8, 6))
plt.pie(datos_duplicados, labels=etiquetas, colors=colores, autopct='%1.1f%%', startangle=90, explode=(0, 0.1))

# Personalizar el gráfico
plt.title('Proporción de Filas Duplicadas', fontsize=14)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# <h4>Verificamos las filas duplicadas</h4>

# %%
# Buscar todas las filas en las que la columna 'name' sea "Porter Pharmacy"
resultado_busqueda = df_business[df_business['name'] == "Porter Pharmacy"]

# Mostrar los resultados
resultado_busqueda.head()
# Out:
#                    name                                            address  \
# 0       Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 26573   Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 275001  Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 550002  Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 825003  Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...
#
#                                       gmap_id description  latitude  \
# 0       0x88f16e41928ff687:0x883dad4fd048e8f8         NaN   32.3883
# 26573   0x88f16e41928ff687:0x883dad4fd048e8f8         NaN   32.3883
# 275001  0x88f16e41928ff687:0x883dad4fd048e8f8         NaN   32.3883
# 550002  0x88f16e41928ff687:0x883dad4fd048e8f8         NaN   32.3883
# 825003  0x88f16e41928ff687:0x883dad4fd048e8f8         NaN   32.3883
#
#         longitude      category  avg_rating  num_of_reviews price  \
# 0        -83.3571  ['Pharmacy']         4.9              16   NaN
# 26573    -83.3571  ['Pharmacy']         4.9              16   NaN
# 275001   -83.3571  ['Pharmacy']         4.9              16   NaN
# 550002   -83.3571  ['Pharmacy']         4.9              16   NaN
# 825003   -83.3571  ['Pharmacy']         4.9              16   NaN
#
#                                                     hours  \
# 0       [['Friday', '8AM–6PM'], ['Saturday', '8AM–12PM...
# 26573   [['Friday', '8AM–6PM'], ['Saturday', '8AM–12PM...
# 275001  [['Friday', '8AM–6PM'], ['Saturday', '8AM–12PM...
# 550002  [['Friday', '8AM–6PM'], ['Saturday', '8AM–12PM...
# 825003  [['Friday', '8AM–6PM'], ['Saturday', '8AM–12PM...
#
#                                                      MISC              state  \
# 0       {'Service options': ['In-store shopping', 'Sam...  Open ⋅ Closes 6PM
# 26573   {'Service options': ['In-store shopping', 'Sam...  Open ⋅ Closes 6PM
# 275001  {'Service options': ['In-store shopping', 'Sam...  Open ⋅ Closes 6PM
# 550002  {'Service options': ['In-store shopping', 'Sam...  Open ⋅ Closes 6PM
# 825003  {'Service options': ['In-store shopping', 'Sam...  Open ⋅ Closes 6PM
#
#                                          relative_results  \
# 0       ['0x88f16e41929435cf:0x5b2532a2885e9ef6', '0x8...
# 26573   ['0x88f16e41929435cf:0x5b2532a2885e9ef6', '0x8...
# 275001  ['0x88f16e41929435cf:0x5b2532a2885e9ef6', '0x8...
# 550002  ['0x88f16e41929435cf:0x5b2532a2885e9ef6', '0x8...
# 825003  ['0x88f16e41929435cf:0x5b2532a2885e9ef6', '0x8...
#
#                                                       url
# 0       https://www.google.com/maps/place//data=!4m2!3...
# 26573   https://www.google.com/maps/place//data=!4m2!3...
# 275001  https://www.google.com/maps/place//data=!4m2!3...
# 550002  https://www.google.com/maps/place//data=!4m2!3...
# 825003  https://www.google.com/maps/place//data=!4m2!3...

# %%
# Buscar todas las filas en las que la columna 'name' sea "Nova Fabrics"
resultado_busqueda = df_business[df_business['name'] == "Nova Fabrics"]

# Mostrar los resultados
resultado_busqueda.head()
# Out:
#                name                                            address  \
# 3      Nova Fabrics  Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 26576  Nova Fabrics  Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
#
#                                     gmap_id description   latitude  longitude  \
# 3      0x80c2c89923b27a41:0x32041559418d447         NaN  34.023669 -118.23293
# 26576  0x80c2c89923b27a41:0x32041559418d447         NaN  34.023669 -118.23293
#
#                category  avg_rating  num_of_reviews price  \
# 3      ['Fabric store']         3.3               6   NaN
# 26576  ['Fabric store']         3.3               6   NaN
#
#                                                    hours  \
# 3      [['Thursday', '9AM–5PM'], ['Friday', '9AM–5PM'...
# 26576  [['Thursday', '9AM–5PM'], ['Friday', '9AM–5PM'...
#
#                                                     MISC              state  \
# 3      {'Service options': ['In-store shopping'], 'Pa...  Open ⋅ Closes 5PM
# 26576  {'Service options': ['In-store shopping'], 'Pa...  Open ⋅ Closes 5PM
#
#                                         relative_results  \
# 3      ['0x80c2c8811477253f:0x23a8a492df1918f7', '0x8...
# 26576  ['0x80c2c8811477253f:0x23a8a492df1918f7', '0x8...
#
#                                                      url
# 3      https://www.google.com/maps/place//data=!4m2!3...
# 26576  https://www.google.com/maps/place//data=!4m2!3...
